# %%
# This is a demo that runs super fast.
# This can be run on Colab for free, thanks to Google.

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# TensorFlow 1.x selected.
# Found GPU at: /device:GPU:0

# %%
from __future__ import print_function, division
import scipy


from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate, Multiply,RepeatVector,Lambda, Add
from keras.layers import BatchNormalization, Activation,MaxPooling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam
import datetime
import matplotlib.pyplot as plt
import sys
from keras.utils import to_categorical
import tensorflow as tf
import numpy as np
import os
from keras import backend as K
from scipy import ndimage
from scipy.ndimage import maximum_filter,zoom,median_filter
# Out:
# Using TensorFlow backend.

# %%
# Author: Wen Pan, Michael Pyrcz, Carlos Torres-Verdin
# Reference: Stochastic Pix2Pix: A New Machine Learning Method for Geophysical and Well Conditioning of Rule-Based Channel Reservoir Models


mydir=F'/content/drive/My Drive/Turbidite/2D2/whole_sand_body/demo/'# main directory
weight_dir=F'/content/drive/My Drive/Turbidite/2D2/whole_sand_body/demo/weight/'# model weight directory
img_dir=F'/content/drive/My Drive/Turbidite/2D2/whole_sand_body/demo/img/'# realization image directory

# when the conditioning reproduction weight is set to be 0, it becomes to be GAN 
weight_JS=1 #weight for Jensen Shannon divergence
weight_well=0.6 # weight for well data
weight_seismic=0.2 # weight for seismic

class Stochastic_pix2pix():
    def __init__(self):
        # Input param
        self.batch_size=16
        #training,output image shape
        self.img_rows = 56
        self.img_cols = 56
        # # of latent variables
        self.latent=20
        # # of facies
        self.channels = 3
        #input and output image shape
        self.img_shape1 = (self.img_rows, self.img_cols, 1)#B seismic outline
        self.img_shape2 = (self.img_rows, self.img_cols, self.channels)#A training,output image shape
        # well location
        self.well_loc=np.array([[13,40],[19,4],[32,29],[33,33],[12,13],[4,46],[44,40],[20,40],[51,15],[28,47]])
        # regions corresponding to largest template size
        # Note we assume nonstationarity (regional stationarity) if they are larger than 1
        self.disc_patch = ( 7,7, 1)
        # number of filters in the first layer of G and D, D's filter size can be infered from the MPS density function.   
        self.gf = 12
        self.df = 6
        # weight optimization param
        optimizer = Adam(0.0008, 0.9)

        # Build and compile the discriminator
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss='binary_crossentropy',
            optimizer=optimizer,
            metrics=['accuracy'])

        #-------------------------
        # Construct Computational
        #   Graph of Generator
        #-------------------------

        # Build the generator
        self.generator = self.build_generator()

        # Input images and their conditioning images (params)
        img_B = Input(shape=self.img_shape1) #seismic outline
        well=Input(shape=self.img_shape1) # well data map
        myrandom=Input(shape=(self.latent,)) # random latent variables

        # Generate conditional realization fake_A, reproduced well data, and seismic outline with generator
        fake_A,fake_well,fake_seismic= self.generator([img_B,myrandom,well])

        # to train the generator to fool the discriminator we will only train the generator
        self.discriminator.trainable = False

        # Discriminator calculates the multi-point statistics and determines if the statistics calculated from training images are reproduced in the realization.
        valid = self.discriminator(fake_A)

        # specify the relative weight for each loss functions
        self.combined = Model(inputs=[img_B,myrandom,well], outputs=[valid,fake_well,fake_seismic])
        self.combined.compile(loss=['binary_crossentropy','categorical_crossentropy','binary_crossentropy'],
                              loss_weights=[weight_JS,weight_well,weight_seismic], 
                              optimizer=optimizer)


    def build_generator(self):
        """U-Net Generator"""

        def conv2d(layer_input, filters, f_size=4, bn=True):
            """Layers used during downsampling"""
            d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input)
            d = LeakyReLU(alpha=0.2)(d)
            if bn:
                d = BatchNormalization(momentum=0.8)(d)
            return d

        def deconv2d(layer_input, skip_input, filters, f_size=4, dropout_rate=0):
            """Layers used during upsampling"""
            u = UpSampling2D(size=2)(layer_input)
            u = Conv2D(filters, kernel_size=f_size, strides=1, padding='same', activation='relu')(u)
            if dropout_rate:
                u = Dropout(dropout_rate)(u)
            u = BatchNormalization(momentum=0.8)(u)
            u = Concatenate()([u, skip_input])
            return u


        # Image input (seismic)
        d0 = Input(shape=self.img_shape1)
        # latent variables
        myrandom=Input(shape=(self.latent,))
        myrandom2=Dense(self.img_rows*self.img_cols)(myrandom)        
        myrandom2=Reshape((self.img_rows,self.img_cols,1))(myrandom2)
        # combine latent variables with seismic input
        combine2=Multiply()([d0, myrandom2])
        #input well data
        mywell=Input(shape=self.img_shape1)
        #combine all 3 inputs
        # combine2=Concatenate(axis=-1)([mywell,combine2])
        combine2=Add()([mywell,combine2])
        # Encoder-Decoder Structure
        d1 = conv2d(combine2, self.gf, bn=False)
        d2 = conv2d(d1, self.gf*2)
        d3 = conv2d(d2, self.gf*4)
        # Start of Decoding
        u8 = deconv2d(d3, d2, self.gf*2)
        u9 = deconv2d(u8, d1, self.gf)
        u10 = UpSampling2D(size=2)(u9)
        u11=Concatenate()([u10,mywell])
        output_img = Conv2D(self.channels, kernel_size=4, strides=1, padding='same', activation='softmax')(u11)

        # Back calculation of seismic data
        seismic0=Lambda( lambda x: x[:,:,:,1:])(output_img)
        seismic=Lambda( lambda x: K.sum(x, axis=-1),name='seismic')(seismic0)
        
        # Back calculation of well data
        wells=[]
        wells.append(Lambda(lambda x: x[:,13:14,40,:])(output_img))
        wells.append(Lambda(lambda x: x[:,19:20,4,:])(output_img))
        wells.append(Lambda(lambda x: x[:,32:33,29,:])(output_img))
        wells.append(Lambda(lambda x: x[:,33:34,33,:])(output_img))
        wells.append(Lambda(lambda x: x[:,12:13,13,:])(output_img))
        wells.append(Lambda(lambda x: x[:,4:5,46,:])(output_img))
        wells.append(Lambda(lambda x: x[:,44:45,40,:])(output_img))
        wells.append(Lambda(lambda x: x[:,20:21,40,:])(output_img))
        wells.append(Lambda(lambda x: x[:,51:52,15,:])(output_img))
        wells.append(Lambda(lambda x: x[:,28:29,47,:])(output_img))            
        well=Concatenate(axis=1)(wells)

        return Model(inputs=[d0,myrandom,mywell], outputs=[output_img,well,seismic])







    def build_discriminator(self):
        # define convolutional down sampling layer
        def d_layer(layer_input, filters, f_size=4, bn=True):
            """Discriminator layer"""
            d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input)
            d = LeakyReLU(alpha=0.2)(d)
            if bn:
                d = BatchNormalization(momentum=0.8)(d)
            return d


        #input training image/output from generator
        img_A = Input(shape=self.img_shape2)
        
        # MPS extraction
        d1 = d_layer(img_A, self.df, bn=False)#128
        d2 = d_layer(d1, self.df*2)#64
        d3 = d_layer(d2, self.df*4)#32
        # Force output between 0 and 1
        validity = Conv2D(1, kernel_size=4, strides=1, padding='same', activation='sigmoid')(d3)

        return Model(img_A, validity)

    def train(self, epochs, batch_size=8, sample_interval=50):

        # Adversarial loss ground truths
        batch_size=self.batch_size
        valid = np.ones((batch_size,) + self.disc_patch)
        fake = np.zeros((batch_size,) + self.disc_patch)  
        # load training images      
        a0=np.load(mydir+'lobe_demo.npy')
        a=a0.copy()
        # keep record of training process
        self.process=[[],[],[],[]]# discriminator accuracy for training image; realization; generator accuracy; discriminator loss; generator loss.
        # imgs_A_all: training images
        imgs_A_all=a.copy()
        # seismic_all: seismic conditioing data for loss calculation
        seismic_all=(a>0).astype(int)
        # imgs_B_all: seismic conditioing data for input
        imgs_B_all=seismic_all.copy()
        imgs_B_all=np.expand_dims(imgs_B_all,axis=-1)
        # well_all: well data for input
        well_all=np.zeros(imgs_B_all.shape)
        for mm in range(self.well_loc.shape[0]):
            well_all[:,self.well_loc[mm,0],self.well_loc[mm,1],0]=(imgs_A_all[:,self.well_loc[mm,0],self.well_loc[mm,1]]+1)/10#input
        # well_dat_all" well data fro loss calculation
        well_dat_all=np.zeros((imgs_B_all.shape[0],self.well_loc.shape[0]))
        for mm in range(self.well_loc.shape[0]):
            well_dat_all[:,mm]=imgs_A_all[:,self.well_loc[mm,0],self.well_loc[mm,1]]#output
        well_dat_all=to_categorical(well_dat_all,self.channels)
        # one-hot encoding for training images
        imgs_A_all=to_categorical(imgs_A_all,self.channels)  
        
        # start of training
        for jj in range(1000):
            for epoch in range(5): 
                # generate random latent input variables
                res_all=np.random.normal(0,1,size=(imgs_B_all.shape[0],self.latent)) 
                ids=np.arange(imgs_B_all.shape[0])
                np.random.shuffle(ids)
                for ii in np.arange(imgs_B_all.shape[0]//batch_size):
                    # divide training data according to their batch size
                    imgs_A=imgs_A_all[ids[int(ii*batch_size):int((ii+1)*batch_size)]]
                    imgs_B=imgs_B_all[ids[int(ii*batch_size):int((ii+1)*batch_size)]]
                    seismic=seismic_all[ids[int(ii*batch_size):int((ii+1)*batch_size)]]
                    well_dat=well_dat_all[ids[int(ii*batch_size):int((ii+1)*batch_size)]]
                    well=well_all[ids[int(ii*batch_size):int((ii+1)*batch_size)]]
                    res=res_all[ids[int(ii*batch_size):int((ii+1)*batch_size)]]

                    # ---------------------
                    #  Train Discriminator
                    # ---------------------
                    # generate fake realization and its associated conditioning data
                    fake_A,fake_well,fake_seismic= self.generator.predict([imgs_B,res,well])
                    # train discrminator to calculate J-S divergence
                    d_loss_real = self.discriminator.train_on_batch(imgs_A, valid)
                    d_loss_fake = self.discriminator.train_on_batch(fake_A, fake)
                    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

                    # -----------------
                    #  Train Generator
                    # -----------------
    
                    # Train the generators
                    g_loss = self.combined.train_on_batch([imgs_B,res,well], [valid,well_dat,seismic])
                    
                    # record of trainign process
                    # accuracy
                    self.process[0].append(d_loss_real[1])
                    self.process[1].append(d_loss_fake[1])
                    # loss
                    self.process[2].append(d_loss[0]) 
                    self.process[3].append(g_loss[0])   

                    # output the training progress
                    if ii%3==0:
                        # calculate well data mismatch
                        myfakewell=np.argmax(fake_well,axis=-1)
                        well_dat2=np.argmax(well_dat,axis=-1)
                        error=np.sum((myfakewell!=well_dat2))/myfakewell.shape[0]

                        print ("[Epoch %d,%d] [D loss: %f, D acc: %3d%%] [G loss: %f][well error:%3d%%] " % (jj, epoch,
                                                                                d_loss[0], 100*d_loss[1],
                                                                                g_loss[0],error*10))  
    
                    # save generated image samples
                    if ii==0 and epoch==0 and jj%3==0:
                        self.save_imgs(jj,imgB=imgs_B[0:1,:,:,:],imgA=imgs_A[0],well=well[0:1])
                    # save weight and training process
                    if ii==0 and epoch==0 and jj%10==0:
                        self.generator.save_weights(weight_dir+'pos_predictor_full_seismic_filt2_sand_whole2_'+str(jj)+'.h5')
                        self.combined.save_weights(weight_dir+'pos_combined_full_seismic_filt2_sand_whole2_'+str(jj)+'.h5')
                        self.discriminator.save_weights(weight_dir+'pos_discriminator_full_seismic_filt2_sand_whole2_'+str(jj)+'.h5')
                        self.save_process()

    def save_process(self):
        plt.figure()
        plt.plot(self.process[0])
        plt.plot(self.process[1])
        plt.ylabel('Accuracy')
        plt.xlabel('Iteration')
        plt.legend(['D_real','D_fake'])
        plt.savefig(mydir+'acc_plot.png',dpi=100)
        plt.close('all')

        plt.figure()
        plt.plot(self.process[2])
        plt.plot(self.process[3])
        plt.ylabel('Loss')
        plt.xlabel('Iteration')
        plt.legend(['D','G'])
        plt.savefig(mydir+'loss_plot.png',dpi=100)
        plt.close('all')        




    def save_imgs(self, ii,imgB,imgA,well):
        # training image
        plt.figure()
        zz=np.argmax(imgA[:,:,:],axis=-1)
        plt.imshow(np.argmax(imgA[:,:,:],axis=-1))
        plt.scatter(self.well_loc[:,0],self.well_loc[:,1],color='red')
        plt.title('Truth Model')
        plt.savefig(img_dir+str(ii)+'_true.png',dpi=100)
        plt.close('all')
        # realization 1
        plt.figure()
        res=np.random.normal(0,1,size=[1,self.latent])
        fake_A,wellfake,seismic = self.generator.predict([imgB,res,well])        
        plt.imshow(np.argmax(fake_A[0,:,:,:],axis=-1))
        plt.title('Realization1')
        plt.savefig(img_dir+str(ii)+'_realization1.png',dpi=100)        
        plt.close('all')
        # realization 2
        plt.figure()
        res=np.random.normal(0,1,size=[1,self.latent])
        fake_A,wellfake,seismic = self.generator.predict([imgB,res,well]) 
        z=np.argmax(fake_A[0,:,:,:],axis=-1)
        plt.imshow(z)
        plt.title('Realization2')
        plt.savefig(img_dir+str(ii)+'_realization2.png',dpi=100)        
        plt.close('all')
        # wel data mismatch map
        plt.figure()
        res=np.random.normal(0,1,size=[1,self.latent])
        fake_A,wellfake,seismic = self.generator.predict([imgB,res,well]) 
        z=np.argmax(fake_A[0,:,:,:],axis=-1)
        z2=np.ones(z.shape)*np.nan
        for i in range(self.well_loc.shape[0]):
            z2[self.well_loc[i,1],self.well_loc[i,0]]=z[self.well_loc[i,0],self.well_loc[i,1]]==zz[self.well_loc[i,0],self.well_loc[i,1]]
        plt.imshow(z2)
        plt.title('Well Data Mismatch')
        plt.savefig(img_dir+str(ii)+'_well_dat.png',dpi=100)        
        plt.close('all')
        return 0

if __name__ == '__main__':
    gan = Stochastic_pix2pix()
    # gan.generator.load_weights(weight_dir+'pos_predictor_full_seismic_filt2_sand_whole2.h5')
    # gan.discriminator.load_weights(weight_dir+'pos_discriminator_full_seismic_filt2_sand_whole2.h5')
    # gan.combined.load_weights(weight_dir+'pos_combined_full_seismic_filt2_sand_whole2.h5')
    gan.train(epochs=1)
# Out:
# /tensorflow-1.15.2/python3.6/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# [Epoch 0,0] [D loss: 0.908283, D acc:  42%] [G loss: 1.885588][well error: 65%]
# /tensorflow-1.15.2/python3.6/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Streaming output truncated to the last 5000 lines.
# [Epoch 952,1] [D loss: 0.170243, D acc:  95%] [G loss: 6.606455][well error: 18%]
# [Epoch 952,2] [D loss: 0.245790, D acc:  90%] [G loss: 3.328258][well error: 15%]
# [Epoch 952,2] [D loss: 0.123468, D acc:  95%] [G loss: 8.223710][well error: 16%]
# [Epoch 952,2] [D loss: 0.031877, D acc:  99%] [G loss: 4.309449][well error: 16%]
# [Epoch 952,2] [D loss: 0.027716, D acc:  99%] [G loss: 6.576991][well error: 11%]
# [Epoch 952,2] [D loss: 0.052535, D acc:  98%] [G loss: 7.378798][well error: 10%]
# [Epoch 952,2] [D loss: 0.012382, D acc:  99%] [G loss: 8.102723][well error: 12%]
# [Epoch 952,2] [D loss: 0.025487, D acc:  99%] [G loss: 12.260651][well error: 16%]
# [Epoch 952,2] [D loss: 0.076310, D acc:  97%] [G loss: 4.844148][well error: 13%]
# [Epoch 952,2] [D loss: 0.042523, D acc:  99%] [G loss: 7.045099][well error: 20%]
# [Epoch 952,2] [D loss: 0.144694, D acc:  93%] [G loss: 14.341000][well error: 15%]
# [Epoch 952,2] [D loss: 0.013977, D acc:  99%] [G loss: 7.668858][well error: 15%]
# [Epoch 952,2] [D loss: 0.020129, D acc:  99%] [G loss: 5.402051][well error: 13%]
# [Epoch 952,2] [D loss: 0.015375, D acc:  99%] [G loss: 7.184012][well error: 13%]
# [Epoch 952,2] [D loss: 0.102002, D acc:  97%] [G loss: 3.387979][well error: 14%]
# [Epoch 952,2] [D loss: 0.108478, D acc:  94%] [G loss: 13.121339][well error: 12%]
# [Epoch 952,2] [D loss: 0.099619, D acc:  96%] [G loss: 8.021284][well error: 15%]
# [Epoch 952,2] [D loss: 0.012834, D acc: 100%] [G loss: 8.325220][well error: 16%]
# [Epoch 952,2] [D loss: 0.016772, D acc:  99%] [G loss: 7.367178][well error: 16%]
# [Epoch 952,2] [D loss: 0.231042, D acc:  91%] [G loss: 7.194881][well error: 18%]
# [Epoch 952,2] [D loss: 0.011655, D acc: 100%] [G loss: 12.096103][well error: 13%]
# [Epoch 952,2] [D loss: 0.046159, D acc:  98%] [G loss: 6.668827][well error: 11%]
# [Epoch 952,3] [D loss: 0.032089, D acc:  99%] [G loss: 1.852324][well error: 13%]
# [Epoch 952,3] [D loss: 0.049860, D acc:  98%] [G loss: 3.419104][well error: 13%]
# [Epoch 952,3] [D loss: 0.012464, D acc: 100%] [G loss: 8.018255][well error: 14%]
# [Epoch 952,3] [D loss: 0.029553, D acc:  99%] [G loss: 9.599804][well error: 16%]
# [Epoch 952,3] [D loss: 0.184272, D acc:  92%] [G loss: 8.183288][well error: 15%]
# [Epoch 952,3] [D loss: 0.020429, D acc:  99%] [G loss: 6.822248][well error: 23%]
# [Epoch 952,3] [D loss: 0.023019, D acc:  99%] [G loss: 8.378576][well error: 15%]
# [Epoch 952,3] [D loss: 0.003913, D acc: 100%] [G loss: 12.920088][well error: 18%]
# [Epoch 952,3] [D loss: 0.017876, D acc:  99%] [G loss: 4.766842][well error: 12%]
# [Epoch 952,3] [D loss: 0.181757, D acc:  92%] [G loss: 3.749611][well error: 20%]
# [Epoch 952,3] [D loss: 0.036015, D acc:  99%] [G loss: 9.097158][well error: 13%]
# [Epoch 952,3] [D loss: 0.075104, D acc:  97%] [G loss: 7.339347][well error: 15%]
# [Epoch 952,3] [D loss: 0.016860, D acc:  99%] [G loss: 8.959635][well error: 16%]
# [Epoch 952,3] [D loss: 0.019186, D acc:  99%] [G loss: 7.640924][well error: 20%]
# [Epoch 952,3] [D loss: 0.060401, D acc:  99%] [G loss: 6.786572][well error: 11%]
# [Epoch 952,3] [D loss: 0.031545, D acc:  99%] [G loss: 7.685666][well error: 16%]
# [Epoch 952,3] [D loss: 0.057563, D acc:  99%] [G loss: 4.670179][well error: 21%]
# [Epoch 952,3] [D loss: 0.015418, D acc:  99%] [G loss: 8.738434][well error: 16%]
# [Epoch 952,3] [D loss: 0.042244, D acc:  99%] [G loss: 6.836232][well error: 19%]
# [Epoch 952,3] [D loss: 0.021339, D acc:  99%] [G loss: 5.658855][well error:  9%]
# [Epoch 952,3] [D loss: 0.073131, D acc:  96%] [G loss: 6.623361][well error: 17%]
# [Epoch 952,4] [D loss: 0.011597, D acc: 100%] [G loss: 9.844781][well error: 16%]
# [Epoch 952,4] [D loss: 0.019820, D acc:  99%] [G loss: 6.106316][well error: 15%]
# [Epoch 952,4] [D loss: 0.054451, D acc:  97%] [G loss: 3.843453][well error: 16%]
# [Epoch 952,4] [D loss: 0.270418, D acc:  87%] [G loss: 2.992959][well error: 17%]
# [Epoch 952,4] [D loss: 0.118770, D acc:  94%] [G loss: 10.445053][well error: 16%]
# [Epoch 952,4] [D loss: 0.072525, D acc:  97%] [G loss: 5.349819][well error: 25%]
# [Epoch 952,4] [D loss: 0.051568, D acc:  97%] [G loss: 6.329924][well error: 16%]
# [Epoch 952,4] [D loss: 0.099803, D acc:  96%] [G loss: 13.702658][well error: 13%]
# [Epoch 952,4] [D loss: 0.069661, D acc:  98%] [G loss: 5.901309][well error: 21%]
# [Epoch 952,4] [D loss: 0.090808, D acc:  97%] [G loss: 6.522913][well error: 15%]
# [Epoch 952,4] [D loss: 0.083969, D acc:  97%] [G loss: 5.156766][well error: 14%]
# [Epoch 952,4] [D loss: 0.259967, D acc:  88%] [G loss: 2.612831][well error: 18%]
# [Epoch 952,4] [D loss: 0.037739, D acc:  99%] [G loss: 6.976402][well error: 15%]
# [Epoch 952,4] [D loss: 0.031866, D acc:  99%] [G loss: 7.695166][well error: 20%]
# [Epoch 952,4] [D loss: 0.025536, D acc:  99%] [G loss: 6.428005][well error: 15%]
# [Epoch 952,4] [D loss: 0.032570, D acc:  99%] [G loss: 5.738358][well error: 18%]
# [Epoch 952,4] [D loss: 0.049710, D acc:  99%] [G loss: 6.499567][well error: 15%]
# [Epoch 952,4] [D loss: 0.071049, D acc:  98%] [G loss: 6.544863][well error: 13%]
# [Epoch 952,4] [D loss: 0.017227, D acc: 100%] [G loss: 6.843119][well error: 15%]
# [Epoch 952,4] [D loss: 0.007088, D acc:  99%] [G loss: 6.633893][well error: 19%]
# [Epoch 952,4] [D loss: 0.013364, D acc:  99%] [G loss: 10.440765][well error: 18%]
# [Epoch 953,0] [D loss: 0.036167, D acc:  99%] [G loss: 10.254419][well error: 18%]
# [Epoch 953,0] [D loss: 0.164282, D acc:  94%] [G loss: 6.716379][well error: 15%]
# [Epoch 953,0] [D loss: 0.035196, D acc:  99%] [G loss: 4.850898][well error: 12%]
# [Epoch 953,0] [D loss: 0.008727, D acc: 100%] [G loss: 8.435194][well error: 18%]
# [Epoch 953,0] [D loss: 0.024636, D acc:  99%] [G loss: 11.293117][well error: 21%]
# [Epoch 953,0] [D loss: 0.106383, D acc:  95%] [G loss: 7.682158][well error: 20%]
# [Epoch 953,0] [D loss: 0.009914, D acc:  99%] [G loss: 7.549765][well error: 20%]
# [Epoch 953,0] [D loss: 0.127753, D acc:  94%] [G loss: 3.271636][well error: 11%]
# [Epoch 953,0] [D loss: 0.012751, D acc: 100%] [G loss: 8.149688][well error: 17%]
# [Epoch 953,0] [D loss: 0.010055, D acc:  99%] [G loss: 9.494134][well error: 15%]
# [Epoch 953,0] [D loss: 0.014128, D acc: 100%] [G loss: 6.704884][well error: 15%]
# [Epoch 953,0] [D loss: 0.022361, D acc:  99%] [G loss: 7.422389][well error: 18%]
# [Epoch 953,0] [D loss: 0.028513, D acc:  99%] [G loss: 8.355597][well error: 16%]
# [Epoch 953,0] [D loss: 0.011845, D acc:  99%] [G loss: 9.876143][well error: 18%]
# [Epoch 953,0] [D loss: 0.056031, D acc:  98%] [G loss: 7.532089][well error: 17%]
# [Epoch 953,0] [D loss: 0.042333, D acc:  98%] [G loss: 9.532085][well error: 15%]
# [Epoch 953,0] [D loss: 0.026054, D acc:  99%] [G loss: 8.660997][well error: 15%]
# [Epoch 953,0] [D loss: 0.094335, D acc:  97%] [G loss: 5.986763][well error: 18%]
# [Epoch 953,0] [D loss: 0.017682, D acc:  99%] [G loss: 7.603892][well error: 18%]
# [Epoch 953,0] [D loss: 0.065838, D acc:  98%] [G loss: 4.120620][well error: 10%]
# [Epoch 953,0] [D loss: 0.017498, D acc:  99%] [G loss: 7.249339][well error: 10%]
# [Epoch 953,1] [D loss: 0.061916, D acc:  98%] [G loss: 7.587581][well error: 16%]
# [Epoch 953,1] [D loss: 0.038102, D acc:  99%] [G loss: 13.026029][well error: 15%]
# [Epoch 953,1] [D loss: 0.012105, D acc:  99%] [G loss: 8.682779][well error: 18%]
# [Epoch 953,1] [D loss: 0.039816, D acc:  98%] [G loss: 6.422763][well error: 16%]
# [Epoch 953,1] [D loss: 0.071984, D acc:  97%] [G loss: 9.713252][well error: 13%]
# [Epoch 953,1] [D loss: 0.052264, D acc:  98%] [G loss: 10.556572][well error: 20%]
# [Epoch 953,1] [D loss: 0.037336, D acc:  99%] [G loss: 8.366459][well error: 23%]
# [Epoch 953,1] [D loss: 0.025298, D acc:  99%] [G loss: 6.635222][well error: 18%]
# [Epoch 953,1] [D loss: 0.044368, D acc:  99%] [G loss: 5.752402][well error: 14%]
# [Epoch 953,1] [D loss: 0.231507, D acc:  88%] [G loss: 7.552352][well error: 11%]
# [Epoch 953,1] [D loss: 0.114368, D acc:  96%] [G loss: 4.202366][well error: 21%]
# [Epoch 953,1] [D loss: 0.010857, D acc:  99%] [G loss: 9.354484][well error: 18%]
# [Epoch 953,1] [D loss: 0.012934, D acc:  99%] [G loss: 9.335918][well error: 16%]
# [Epoch 953,1] [D loss: 0.023304, D acc:  99%] [G loss: 7.253032][well error: 16%]
# [Epoch 953,1] [D loss: 0.034519, D acc:  99%] [G loss: 7.905114][well error: 16%]
# [Epoch 953,1] [D loss: 0.074303, D acc:  98%] [G loss: 6.585225][well error: 13%]
# [Epoch 953,1] [D loss: 0.032293, D acc:  99%] [G loss: 8.581979][well error: 13%]
# [Epoch 953,1] [D loss: 0.053907, D acc:  98%] [G loss: 9.620445][well error: 15%]
# [Epoch 953,1] [D loss: 0.041683, D acc:  99%] [G loss: 8.637981][well error: 19%]
# [Epoch 953,1] [D loss: 0.052242, D acc:  98%] [G loss: 7.813470][well error: 11%]
# [Epoch 953,1] [D loss: 0.394377, D acc:  82%] [G loss: 6.727644][well error: 19%]
# [Epoch 953,2] [D loss: 0.136001, D acc:  94%] [G loss: 11.453775][well error: 20%]
# [Epoch 953,2] [D loss: 0.134808, D acc:  94%] [G loss: 10.991862][well error: 15%]
# [Epoch 953,2] [D loss: 0.235434, D acc:  89%] [G loss: 4.627983][well error: 15%]
# [Epoch 953,2] [D loss: 0.030016, D acc:  99%] [G loss: 8.887176][well error: 15%]
# [Epoch 953,2] [D loss: 0.030911, D acc:  99%] [G loss: 8.787169][well error: 15%]
# [Epoch 953,2] [D loss: 0.068332, D acc:  98%] [G loss: 7.725157][well error: 16%]
# [Epoch 953,2] [D loss: 0.088090, D acc:  97%] [G loss: 3.279463][well error: 16%]
# [Epoch 953,2] [D loss: 0.054746, D acc:  98%] [G loss: 7.358519][well error: 19%]
# [Epoch 953,2] [D loss: 0.119937, D acc:  94%] [G loss: 11.492515][well error: 21%]
# [Epoch 953,2] [D loss: 0.011028, D acc:  99%] [G loss: 7.427927][well error: 16%]
# [Epoch 953,2] [D loss: 0.019776, D acc:  99%] [G loss: 8.944560][well error: 18%]
# [Epoch 953,2] [D loss: 0.255250, D acc:  89%] [G loss: 5.780106][well error: 13%]
# [Epoch 953,2] [D loss: 0.050427, D acc:  98%] [G loss: 5.796534][well error: 16%]
# [Epoch 953,2] [D loss: 0.080594, D acc:  97%] [G loss: 1.880518][well error: 15%]
# [Epoch 953,2] [D loss: 0.022339, D acc:  99%] [G loss: 6.499769][well error: 12%]
# [Epoch 953,2] [D loss: 0.018343, D acc: 100%] [G loss: 9.958209][well error: 18%]
# [Epoch 953,2] [D loss: 0.015148, D acc:  99%] [G loss: 12.075188][well error: 14%]
# [Epoch 953,2] [D loss: 0.069708, D acc:  97%] [G loss: 10.252471][well error: 15%]
# [Epoch 953,2] [D loss: 0.067015, D acc:  98%] [G loss: 7.449179][well error: 16%]
# [Epoch 953,2] [D loss: 0.296064, D acc:  86%] [G loss: 4.470720][well error: 15%]
# [Epoch 953,2] [D loss: 0.622220, D acc:  75%] [G loss: 8.427674][well error: 16%]
# [Epoch 953,3] [D loss: 0.241556, D acc:  88%] [G loss: 4.249638][well error: 20%]
# [Epoch 953,3] [D loss: 0.008222, D acc:  99%] [G loss: 7.823647][well error: 13%]
# [Epoch 953,3] [D loss: 0.029573, D acc:  99%] [G loss: 10.232322][well error: 19%]
# [Epoch 953,3] [D loss: 0.028754, D acc:  99%] [G loss: 5.961730][well error: 16%]
# [Epoch 953,3] [D loss: 0.054765, D acc:  98%] [G loss: 5.182701][well error: 12%]
# [Epoch 953,3] [D loss: 0.081747, D acc:  97%] [G loss: 7.679253][well error: 20%]
# [Epoch 953,3] [D loss: 0.018905, D acc:  99%] [G loss: 11.309361][well error: 17%]
# [Epoch 953,3] [D loss: 0.018200, D acc:  99%] [G loss: 10.846176][well error: 16%]
# [Epoch 953,3] [D loss: 0.162827, D acc:  91%] [G loss: 10.488817][well error: 15%]
# [Epoch 953,3] [D loss: 0.160799, D acc:  92%] [G loss: 3.640219][well error: 15%]
# [Epoch 953,3] [D loss: 0.067862, D acc:  98%] [G loss: 6.384989][well error: 17%]
# [Epoch 953,3] [D loss: 0.097804, D acc:  96%] [G loss: 11.393843][well error: 14%]
# [Epoch 953,3] [D loss: 0.023060, D acc:  99%] [G loss: 7.763966][well error: 20%]
# [Epoch 953,3] [D loss: 0.109262, D acc:  95%] [G loss: 5.254565][well error: 15%]
# [Epoch 953,3] [D loss: 0.059767, D acc:  99%] [G loss: 3.112778][well error: 13%]
# [Epoch 953,3] [D loss: 0.116271, D acc:  95%] [G loss: 10.770837][well error: 18%]
# [Epoch 953,3] [D loss: 0.055521, D acc:  98%] [G loss: 9.186453][well error: 17%]
# [Epoch 953,3] [D loss: 0.005495, D acc:  99%] [G loss: 10.964461][well error: 15%]
# [Epoch 953,3] [D loss: 0.046461, D acc:  99%] [G loss: 5.811872][well error: 13%]
# [Epoch 953,3] [D loss: 0.065213, D acc:  98%] [G loss: 5.045343][well error: 18%]
# [Epoch 953,3] [D loss: 0.007311, D acc: 100%] [G loss: 9.400532][well error: 16%]
# [Epoch 953,4] [D loss: 0.084057, D acc:  97%] [G loss: 7.187114][well error: 14%]
# [Epoch 953,4] [D loss: 0.002718, D acc: 100%] [G loss: 9.317720][well error: 11%]
# [Epoch 953,4] [D loss: 0.066513, D acc:  99%] [G loss: 8.279062][well error: 11%]
# [Epoch 953,4] [D loss: 0.064617, D acc:  98%] [G loss: 2.971927][well error: 13%]
# [Epoch 953,4] [D loss: 0.040335, D acc:  99%] [G loss: 6.587922][well error: 16%]
# [Epoch 953,4] [D loss: 0.025884, D acc:  99%] [G loss: 11.300972][well error: 10%]
# [Epoch 953,4] [D loss: 0.099247, D acc:  96%] [G loss: 2.760079][well error: 16%]
# [Epoch 953,4] [D loss: 0.075835, D acc:  97%] [G loss: 7.419570][well error: 13%]
# [Epoch 953,4] [D loss: 0.092566, D acc:  98%] [G loss: 6.942659][well error: 15%]
# [Epoch 953,4] [D loss: 0.111375, D acc:  97%] [G loss: 5.303923][well error: 19%]
# [Epoch 953,4] [D loss: 0.027985, D acc:  99%] [G loss: 6.392377][well error: 18%]
# [Epoch 953,4] [D loss: 0.014734, D acc: 100%] [G loss: 6.083314][well error: 18%]
# [Epoch 953,4] [D loss: 0.097512, D acc:  97%] [G loss: 3.145019][well error: 18%]
# [Epoch 953,4] [D loss: 0.031778, D acc:  99%] [G loss: 11.130149][well error: 20%]
# [Epoch 953,4] [D loss: 0.009065, D acc:  99%] [G loss: 7.130849][well error: 15%]
# [Epoch 953,4] [D loss: 0.009770, D acc:  99%] [G loss: 8.753780][well error: 15%]
# [Epoch 953,4] [D loss: 0.055439, D acc:  99%] [G loss: 15.276284][well error: 13%]
# [Epoch 953,4] [D loss: 1.354740, D acc:  56%] [G loss: 0.655804][well error: 15%]
# [Epoch 953,4] [D loss: 0.069172, D acc:  98%] [G loss: 9.980865][well error: 13%]
# [Epoch 953,4] [D loss: 0.071820, D acc:  97%] [G loss: 7.757444][well error: 15%]
# [Epoch 953,4] [D loss: 0.409809, D acc:  78%] [G loss: 2.682383][well error: 18%]
# [Epoch 954,0] [D loss: 0.013111, D acc:  99%] [G loss: 9.848115][well error: 13%]
# [Epoch 954,0] [D loss: 0.346606, D acc:  83%] [G loss: 6.900088][well error: 11%]
# [Epoch 954,0] [D loss: 0.102639, D acc:  96%] [G loss: 5.756538][well error: 13%]
# [Epoch 954,0] [D loss: 0.028867, D acc:  99%] [G loss: 7.129874][well error: 16%]
# [Epoch 954,0] [D loss: 0.018575, D acc:  99%] [G loss: 8.159517][well error: 13%]
# [Epoch 954,0] [D loss: 0.048914, D acc:  98%] [G loss: 6.875818][well error: 12%]
# [Epoch 954,0] [D loss: 0.031855, D acc:  99%] [G loss: 7.192598][well error: 23%]
# [Epoch 954,0] [D loss: 0.059164, D acc:  98%] [G loss: 7.494608][well error: 13%]
# [Epoch 954,0] [D loss: 0.022075, D acc:  99%] [G loss: 9.650315][well error: 15%]
# [Epoch 954,0] [D loss: 0.007896, D acc:  99%] [G loss: 9.394006][well error: 14%]
# [Epoch 954,0] [D loss: 0.130841, D acc:  95%] [G loss: 3.490980][well error: 11%]
# [Epoch 954,0] [D loss: 0.008410, D acc: 100%] [G loss: 5.737757][well error: 16%]
# [Epoch 954,0] [D loss: 0.029337, D acc:  99%] [G loss: 7.200554][well error: 16%]
# [Epoch 954,0] [D loss: 0.014360, D acc:  99%] [G loss: 8.493231][well error: 15%]
# [Epoch 954,0] [D loss: 0.064244, D acc:  98%] [G loss: 8.798630][well error: 11%]
# [Epoch 954,0] [D loss: 0.014468, D acc:  99%] [G loss: 10.811181][well error: 15%]
# [Epoch 954,0] [D loss: 0.073873, D acc:  97%] [G loss: 7.874876][well error: 13%]
# [Epoch 954,0] [D loss: 0.076044, D acc:  97%] [G loss: 6.405589][well error: 11%]
# [Epoch 954,0] [D loss: 0.008271, D acc: 100%] [G loss: 7.250060][well error: 13%]
# [Epoch 954,0] [D loss: 0.037256, D acc:  99%] [G loss: 6.134474][well error: 13%]
# [Epoch 954,0] [D loss: 0.018670, D acc:  99%] [G loss: 6.754746][well error: 19%]
# [Epoch 954,1] [D loss: 0.026171, D acc:  99%] [G loss: 8.007167][well error: 17%]
# [Epoch 954,1] [D loss: 0.008932, D acc: 100%] [G loss: 7.753718][well error: 16%]
# [Epoch 954,1] [D loss: 0.053716, D acc:  98%] [G loss: 3.384490][well error: 13%]
# [Epoch 954,1] [D loss: 0.035987, D acc:  99%] [G loss: 10.692342][well error: 20%]
# [Epoch 954,1] [D loss: 0.047600, D acc:  98%] [G loss: 7.514081][well error: 12%]
# [Epoch 954,1] [D loss: 0.051740, D acc:  99%] [G loss: 5.444633][well error: 13%]
# [Epoch 954,1] [D loss: 0.028659, D acc:  99%] [G loss: 7.075436][well error: 20%]
# [Epoch 954,1] [D loss: 0.093793, D acc:  97%] [G loss: 9.335490][well error: 18%]
# [Epoch 954,1] [D loss: 0.026498, D acc:  99%] [G loss: 7.260939][well error: 13%]
# [Epoch 954,1] [D loss: 0.031633, D acc:  99%] [G loss: 9.977351][well error: 15%]
# [Epoch 954,1] [D loss: 0.031541, D acc:  99%] [G loss: 10.478866][well error:  8%]
# [Epoch 954,1] [D loss: 0.056569, D acc:  98%] [G loss: 9.411935][well error: 15%]
# [Epoch 954,1] [D loss: 0.034123, D acc:  99%] [G loss: 5.843989][well error: 14%]
# [Epoch 954,1] [D loss: 0.023875, D acc:  99%] [G loss: 5.530565][well error: 18%]
# [Epoch 954,1] [D loss: 0.174498, D acc:  93%] [G loss: 5.202691][well error: 18%]
# [Epoch 954,1] [D loss: 0.018156, D acc:  99%] [G loss: 9.163193][well error: 15%]
# [Epoch 954,1] [D loss: 0.036486, D acc:  99%] [G loss: 9.947794][well error: 17%]
# [Epoch 954,1] [D loss: 0.010326, D acc:  99%] [G loss: 8.671153][well error: 19%]
# [Epoch 954,1] [D loss: 0.055028, D acc:  98%] [G loss: 5.855390][well error: 13%]
# [Epoch 954,1] [D loss: 0.009595, D acc: 100%] [G loss: 7.299024][well error: 16%]
# [Epoch 954,1] [D loss: 0.026822, D acc:  99%] [G loss: 3.418611][well error: 15%]
# [Epoch 954,2] [D loss: 0.031602, D acc:  99%] [G loss: 7.181904][well error: 17%]
# [Epoch 954,2] [D loss: 0.010508, D acc: 100%] [G loss: 10.487281][well error:  8%]
# [Epoch 954,2] [D loss: 0.523365, D acc:  74%] [G loss: 14.445818][well error: 16%]
# [Epoch 954,2] [D loss: 0.082466, D acc:  97%] [G loss: 8.725500][well error: 15%]
# [Epoch 954,2] [D loss: 0.034750, D acc:  99%] [G loss: 6.883050][well error: 14%]
# [Epoch 954,2] [D loss: 0.017411, D acc:  99%] [G loss: 9.930868][well error: 14%]
# [Epoch 954,2] [D loss: 0.310297, D acc:  86%] [G loss: 5.881642][well error: 18%]
# [Epoch 954,2] [D loss: 0.053101, D acc:  99%] [G loss: 5.516709][well error: 23%]
# [Epoch 954,2] [D loss: 0.131959, D acc:  95%] [G loss: 4.770565][well error: 18%]
# [Epoch 954,2] [D loss: 0.102227, D acc:  95%] [G loss: 9.993502][well error: 14%]
# [Epoch 954,2] [D loss: 0.070022, D acc:  98%] [G loss: 6.419501][well error: 14%]
# [Epoch 954,2] [D loss: 0.033082, D acc:  99%] [G loss: 8.316687][well error: 13%]
# [Epoch 954,2] [D loss: 0.013136, D acc:  99%] [G loss: 7.296390][well error: 13%]
# [Epoch 954,2] [D loss: 0.060339, D acc:  98%] [G loss: 3.350178][well error: 16%]
# [Epoch 954,2] [D loss: 0.028966, D acc:  99%] [G loss: 12.949783][well error: 15%]
# [Epoch 954,2] [D loss: 0.030946, D acc:  99%] [G loss: 6.174594][well error: 15%]
# [Epoch 954,2] [D loss: 0.068861, D acc:  98%] [G loss: 10.711803][well error: 18%]
# [Epoch 954,2] [D loss: 0.041259, D acc:  99%] [G loss: 8.835402][well error: 13%]
# [Epoch 954,2] [D loss: 0.049911, D acc:  98%] [G loss: 8.235573][well error: 18%]
# [Epoch 954,2] [D loss: 0.026108, D acc:  99%] [G loss: 6.558424][well error: 18%]
# [Epoch 954,2] [D loss: 0.012863, D acc:  99%] [G loss: 4.119991][well error: 19%]
# [Epoch 954,3] [D loss: 0.034162, D acc:  99%] [G loss: 10.833254][well error: 14%]
# [Epoch 954,3] [D loss: 0.051527, D acc:  98%] [G loss: 13.012420][well error: 19%]
# [Epoch 954,3] [D loss: 0.063454, D acc:  98%] [G loss: 13.205065][well error: 11%]
# [Epoch 954,3] [D loss: 0.085600, D acc:  96%] [G loss: 4.886723][well error: 20%]
# [Epoch 954,3] [D loss: 0.069640, D acc:  97%] [G loss: 4.000971][well error: 13%]
# [Epoch 954,3] [D loss: 0.049781, D acc:  98%] [G loss: 6.951259][well error: 18%]
# [Epoch 954,3] [D loss: 0.017871, D acc:  99%] [G loss: 7.268415][well error: 17%]
# [Epoch 954,3] [D loss: 0.026859, D acc:  99%] [G loss: 7.948704][well error: 16%]
# [Epoch 954,3] [D loss: 0.074444, D acc:  97%] [G loss: 10.622581][well error: 14%]
# [Epoch 954,3] [D loss: 0.052274, D acc:  99%] [G loss: 7.482038][well error: 14%]
# [Epoch 954,3] [D loss: 0.089591, D acc:  96%] [G loss: 5.853313][well error: 17%]
# [Epoch 954,3] [D loss: 0.088843, D acc:  96%] [G loss: 9.514934][well error: 16%]
# [Epoch 954,3] [D loss: 0.153623, D acc:  93%] [G loss: 9.017852][well error: 15%]
# [Epoch 954,3] [D loss: 0.025285, D acc:  99%] [G loss: 3.927912][well error: 11%]
# [Epoch 954,3] [D loss: 0.017286, D acc:  99%] [G loss: 9.258307][well error: 14%]
# [Epoch 954,3] [D loss: 0.484513, D acc:  77%] [G loss: 13.821678][well error: 13%]
# [Epoch 954,3] [D loss: 0.013607, D acc:  99%] [G loss: 6.037414][well error: 18%]
# [Epoch 954,3] [D loss: 0.115284, D acc:  97%] [G loss: 4.026307][well error: 16%]
# [Epoch 954,3] [D loss: 0.039194, D acc:  98%] [G loss: 10.612453][well error: 17%]
# [Epoch 954,3] [D loss: 0.011895, D acc:  99%] [G loss: 8.905066][well error: 14%]
# [Epoch 954,3] [D loss: 0.014418, D acc:  99%] [G loss: 9.594195][well error: 20%]
# [Epoch 954,4] [D loss: 0.074097, D acc:  97%] [G loss: 6.460486][well error: 15%]
# [Epoch 954,4] [D loss: 0.029216, D acc:  99%] [G loss: 5.968327][well error: 12%]
# [Epoch 954,4] [D loss: 0.013230, D acc: 100%] [G loss: 7.584040][well error: 16%]
# [Epoch 954,4] [D loss: 0.018435, D acc:  99%] [G loss: 6.860068][well error: 16%]
# [Epoch 954,4] [D loss: 0.019048, D acc:  99%] [G loss: 9.250985][well error: 19%]
# [Epoch 954,4] [D loss: 0.038222, D acc:  99%] [G loss: 7.419030][well error: 16%]
# [Epoch 954,4] [D loss: 0.002824, D acc: 100%] [G loss: 7.573769][well error: 13%]
# [Epoch 954,4] [D loss: 0.005561, D acc:  99%] [G loss: 8.722875][well error: 15%]
# [Epoch 954,4] [D loss: 0.046804, D acc:  99%] [G loss: 9.017971][well error: 17%]
# [Epoch 954,4] [D loss: 0.060243, D acc:  98%] [G loss: 7.221548][well error: 19%]
# [Epoch 954,4] [D loss: 0.018627, D acc:  99%] [G loss: 6.523953][well error: 14%]
# [Epoch 954,4] [D loss: 0.008660, D acc: 100%] [G loss: 10.766138][well error: 13%]
# [Epoch 954,4] [D loss: 0.012798, D acc:  99%] [G loss: 7.880683][well error: 17%]
# [Epoch 954,4] [D loss: 0.017951, D acc:  99%] [G loss: 5.511145][well error: 21%]
# [Epoch 954,4] [D loss: 0.065084, D acc:  97%] [G loss: 8.874093][well error: 10%]
# [Epoch 954,4] [D loss: 0.021188, D acc:  99%] [G loss: 6.462464][well error: 13%]
# [Epoch 954,4] [D loss: 0.041890, D acc:  98%] [G loss: 7.824426][well error: 16%]
# [Epoch 954,4] [D loss: 0.015953, D acc:  99%] [G loss: 10.418732][well error: 14%]
# [Epoch 954,4] [D loss: 0.185238, D acc:  90%] [G loss: 5.648189][well error: 11%]
# [Epoch 954,4] [D loss: 0.020477, D acc:  99%] [G loss: 7.107670][well error: 13%]
# [Epoch 954,4] [D loss: 0.009656, D acc: 100%] [G loss: 8.010107][well error: 14%]
# [Epoch 955,0] [D loss: 0.034252, D acc:  99%] [G loss: 7.616845][well error: 14%]
# [Epoch 955,0] [D loss: 0.073571, D acc:  97%] [G loss: 7.278817][well error: 12%]
# [Epoch 955,0] [D loss: 0.009603, D acc:  99%] [G loss: 13.153371][well error: 16%]
# [Epoch 955,0] [D loss: 0.047363, D acc:  98%] [G loss: 5.515872][well error: 16%]
# [Epoch 955,0] [D loss: 0.031469, D acc:  99%] [G loss: 8.565163][well error:  8%]
# [Epoch 955,0] [D loss: 0.142167, D acc:  95%] [G loss: 3.732555][well error: 13%]
# [Epoch 955,0] [D loss: 0.011686, D acc:  99%] [G loss: 11.596491][well error: 14%]
# [Epoch 955,0] [D loss: 0.099049, D acc:  96%] [G loss: 7.220635][well error: 17%]
# [Epoch 955,0] [D loss: 0.030219, D acc:  99%] [G loss: 9.517709][well error: 10%]
# [Epoch 955,0] [D loss: 0.027477, D acc:  99%] [G loss: 3.801300][well error: 11%]
# [Epoch 955,0] [D loss: 0.010180, D acc:  99%] [G loss: 7.822822][well error: 11%]
# [Epoch 955,0] [D loss: 0.008479, D acc: 100%] [G loss: 9.199095][well error: 14%]
# [Epoch 955,0] [D loss: 0.022577, D acc: 100%] [G loss: 6.197686][well error: 15%]
# [Epoch 955,0] [D loss: 0.009383, D acc: 100%] [G loss: 8.798031][well error: 14%]
# [Epoch 955,0] [D loss: 0.009234, D acc: 100%] [G loss: 8.234759][well error: 17%]
# [Epoch 955,0] [D loss: 0.070162, D acc:  98%] [G loss: 7.525819][well error: 11%]
# [Epoch 955,0] [D loss: 0.031520, D acc:  99%] [G loss: 5.517955][well error: 21%]
# [Epoch 955,0] [D loss: 0.022572, D acc:  99%] [G loss: 6.807681][well error: 15%]
# [Epoch 955,0] [D loss: 0.268565, D acc:  88%] [G loss: 7.765626][well error: 12%]
# [Epoch 955,0] [D loss: 0.427432, D acc:  79%] [G loss: 6.698970][well error: 12%]
# [Epoch 955,0] [D loss: 0.478311, D acc:  76%] [G loss: 13.290241][well error: 13%]
# [Epoch 955,1] [D loss: 0.030003, D acc:  99%] [G loss: 8.462700][well error: 16%]
# [Epoch 955,1] [D loss: 0.004834, D acc: 100%] [G loss: 5.820494][well error: 15%]
# [Epoch 955,1] [D loss: 0.030483, D acc:  99%] [G loss: 6.455307][well error: 11%]
# [Epoch 955,1] [D loss: 0.060666, D acc:  98%] [G loss: 4.415910][well error: 11%]
# [Epoch 955,1] [D loss: 0.013832, D acc:  99%] [G loss: 9.708864][well error: 20%]
# [Epoch 955,1] [D loss: 0.062767, D acc:  98%] [G loss: 8.072303][well error: 14%]
# [Epoch 955,1] [D loss: 0.047090, D acc:  99%] [G loss: 6.478593][well error: 18%]
# [Epoch 955,1] [D loss: 0.036433, D acc:  99%] [G loss: 8.295839][well error: 11%]
# [Epoch 955,1] [D loss: 0.058036, D acc:  98%] [G loss: 6.257301][well error: 11%]
# [Epoch 955,1] [D loss: 0.044345, D acc:  99%] [G loss: 7.527961][well error: 16%]
# [Epoch 955,1] [D loss: 0.030570, D acc: 100%] [G loss: 7.600856][well error: 11%]
# [Epoch 955,1] [D loss: 0.014384, D acc:  99%] [G loss: 12.941210][well error: 17%]
# [Epoch 955,1] [D loss: 0.007564, D acc: 100%] [G loss: 8.818404][well error: 16%]
# [Epoch 955,1] [D loss: 0.042698, D acc:  99%] [G loss: 7.237094][well error: 13%]
# [Epoch 955,1] [D loss: 0.010988, D acc: 100%] [G loss: 7.274333][well error: 13%]
# [Epoch 955,1] [D loss: 0.008348, D acc: 100%] [G loss: 7.737001][well error: 20%]
# [Epoch 955,1] [D loss: 0.030982, D acc:  99%] [G loss: 4.805418][well error: 20%]
# [Epoch 955,1] [D loss: 0.041360, D acc:  98%] [G loss: 7.075720][well error: 16%]
# [Epoch 955,1] [D loss: 0.048249, D acc:  98%] [G loss: 6.684253][well error: 11%]
# [Epoch 955,1] [D loss: 0.096442, D acc:  97%] [G loss: 11.238604][well error: 13%]
# [Epoch 955,1] [D loss: 0.038338, D acc:  99%] [G loss: 5.834710][well error: 16%]
# [Epoch 955,2] [D loss: 0.017403, D acc:  99%] [G loss: 7.944897][well error: 16%]
# [Epoch 955,2] [D loss: 0.028741, D acc:  99%] [G loss: 8.499079][well error: 18%]
# [Epoch 955,2] [D loss: 0.030372, D acc:  99%] [G loss: 7.094791][well error: 16%]
# [Epoch 955,2] [D loss: 0.025073, D acc:  99%] [G loss: 4.931701][well error: 12%]
# [Epoch 955,2] [D loss: 0.007495, D acc: 100%] [G loss: 8.127709][well error: 15%]
# [Epoch 955,2] [D loss: 0.070819, D acc:  98%] [G loss: 5.090606][well error: 13%]
# [Epoch 955,2] [D loss: 0.010173, D acc:  99%] [G loss: 11.768048][well error: 13%]
# [Epoch 955,2] [D loss: 0.031094, D acc:  99%] [G loss: 8.571095][well error: 13%]
# [Epoch 955,2] [D loss: 0.014438, D acc: 100%] [G loss: 6.262067][well error: 10%]
# [Epoch 955,2] [D loss: 0.032563, D acc:  99%] [G loss: 7.963505][well error: 16%]
# [Epoch 955,2] [D loss: 0.069873, D acc:  98%] [G loss: 6.769703][well error: 15%]
# [Epoch 955,2] [D loss: 0.010786, D acc: 100%] [G loss: 9.648642][well error: 13%]
# [Epoch 955,2] [D loss: 0.052672, D acc:  99%] [G loss: 8.746867][well error: 13%]
# [Epoch 955,2] [D loss: 0.092970, D acc:  97%] [G loss: 8.510606][well error: 14%]
# [Epoch 955,2] [D loss: 0.019795, D acc:  99%] [G loss: 5.255231][well error: 15%]
# [Epoch 955,2] [D loss: 0.313114, D acc:  86%] [G loss: 2.772770][well error: 11%]
# [Epoch 955,2] [D loss: 0.033720, D acc:  98%] [G loss: 12.831319][well error: 13%]
# [Epoch 955,2] [D loss: 0.143647, D acc:  93%] [G loss: 11.104683][well error: 12%]
# [Epoch 955,2] [D loss: 0.048275, D acc:  98%] [G loss: 3.383898][well error: 12%]
# [Epoch 955,2] [D loss: 0.240513, D acc:  89%] [G loss: 4.120879][well error: 11%]
# [Epoch 955,2] [D loss: 0.073563, D acc:  97%] [G loss: 11.689706][well error: 20%]
# [Epoch 955,3] [D loss: 0.025384, D acc:  99%] [G loss: 9.526804][well error: 19%]
# [Epoch 955,3] [D loss: 0.031602, D acc:  99%] [G loss: 6.455739][well error: 13%]
# [Epoch 955,3] [D loss: 0.193969, D acc:  91%] [G loss: 4.467032][well error: 16%]
# [Epoch 955,3] [D loss: 0.026798, D acc:  99%] [G loss: 10.046102][well error: 11%]
# [Epoch 955,3] [D loss: 0.164283, D acc:  93%] [G loss: 10.694533][well error: 15%]
# [Epoch 955,3] [D loss: 0.073716, D acc:  98%] [G loss: 7.729589][well error: 13%]
# [Epoch 955,3] [D loss: 0.021571, D acc:  99%] [G loss: 5.087615][well error: 16%]
# [Epoch 955,3] [D loss: 0.040798, D acc:  98%] [G loss: 5.770905][well error: 16%]
# [Epoch 955,3] [D loss: 0.041020, D acc:  99%] [G loss: 7.108535][well error: 16%]
# [Epoch 955,3] [D loss: 0.145552, D acc:  93%] [G loss: 9.348394][well error:  8%]
# [Epoch 955,3] [D loss: 0.044994, D acc:  99%] [G loss: 4.867531][well error: 10%]
# [Epoch 955,3] [D loss: 0.040378, D acc:  99%] [G loss: 8.920433][well error: 16%]
# [Epoch 955,3] [D loss: 0.021451, D acc:  99%] [G loss: 8.423457][well error: 11%]
# [Epoch 955,3] [D loss: 0.031613, D acc:  99%] [G loss: 4.426829][well error: 13%]
# [Epoch 955,3] [D loss: 0.009866, D acc: 100%] [G loss: 11.419160][well error: 18%]
# [Epoch 955,3] [D loss: 0.457104, D acc:  81%] [G loss: 7.815674][well error: 18%]
# [Epoch 955,3] [D loss: 0.043159, D acc:  98%] [G loss: 4.350843][well error: 10%]
# [Epoch 955,3] [D loss: 0.029858, D acc:  99%] [G loss: 14.644788][well error: 14%]
# [Epoch 955,3] [D loss: 0.020540, D acc:  99%] [G loss: 9.256731][well error: 16%]
# [Epoch 955,3] [D loss: 0.108720, D acc:  97%] [G loss: 3.706299][well error: 14%]
# [Epoch 955,3] [D loss: 0.008314, D acc:  99%] [G loss: 7.080538][well error: 18%]
# [Epoch 955,4] [D loss: 0.025049, D acc:  99%] [G loss: 9.128304][well error: 15%]
# [Epoch 955,4] [D loss: 0.047195, D acc:  99%] [G loss: 5.392304][well error: 16%]
# [Epoch 955,4] [D loss: 0.199279, D acc:  91%] [G loss: 5.480444][well error: 13%]
# [Epoch 955,4] [D loss: 0.010557, D acc: 100%] [G loss: 9.607188][well error: 14%]
# [Epoch 955,4] [D loss: 0.102383, D acc:  96%] [G loss: 10.554811][well error: 16%]
# [Epoch 955,4] [D loss: 0.229346, D acc:  89%] [G loss: 3.827662][well error: 20%]
# [Epoch 955,4] [D loss: 0.016334, D acc:  99%] [G loss: 8.583940][well error: 10%]
# [Epoch 955,4] [D loss: 0.663609, D acc:  76%] [G loss: 3.492572][well error: 14%]
# [Epoch 955,4] [D loss: 0.062225, D acc:  98%] [G loss: 5.703177][well error: 15%]
# [Epoch 955,4] [D loss: 0.040797, D acc:  99%] [G loss: 5.062612][well error: 13%]
# [Epoch 955,4] [D loss: 0.019181, D acc:  99%] [G loss: 7.755239][well error: 16%]
# [Epoch 955,4] [D loss: 0.149742, D acc:  94%] [G loss: 6.751992][well error: 11%]
# [Epoch 955,4] [D loss: 0.046671, D acc:  99%] [G loss: 7.576924][well error: 13%]
# [Epoch 955,4] [D loss: 0.070016, D acc:  97%] [G loss: 13.322136][well error: 15%]
# [Epoch 955,4] [D loss: 0.134658, D acc:  94%] [G loss: 3.484175][well error: 13%]
# [Epoch 955,4] [D loss: 0.016002, D acc:  99%] [G loss: 4.745989][well error: 15%]
# [Epoch 955,4] [D loss: 0.022308, D acc:  99%] [G loss: 4.714097][well error: 15%]
# [Epoch 955,4] [D loss: 0.063500, D acc:  98%] [G loss: 5.489249][well error: 13%]
# [Epoch 955,4] [D loss: 0.014091, D acc: 100%] [G loss: 4.392126][well error: 11%]
# [Epoch 955,4] [D loss: 0.020751, D acc:  99%] [G loss: 9.768662][well error: 11%]
# [Epoch 955,4] [D loss: 0.019024, D acc:  99%] [G loss: 9.421106][well error: 15%]
# [Epoch 956,0] [D loss: 0.033333, D acc:  99%] [G loss: 9.812484][well error: 18%]
# [Epoch 956,0] [D loss: 0.018807, D acc:  99%] [G loss: 10.705582][well error: 14%]
# [Epoch 956,0] [D loss: 0.014871, D acc: 100%] [G loss: 6.568898][well error: 10%]
# [Epoch 956,0] [D loss: 0.014609, D acc:  99%] [G loss: 7.001003][well error: 15%]
# [Epoch 956,0] [D loss: 0.035799, D acc:  99%] [G loss: 7.056060][well error:  8%]
# [Epoch 956,0] [D loss: 0.120673, D acc:  95%] [G loss: 9.460034][well error: 13%]
# [Epoch 956,0] [D loss: 0.006990, D acc: 100%] [G loss: 7.706909][well error: 17%]
# [Epoch 956,0] [D loss: 0.065112, D acc:  98%] [G loss: 4.669081][well error: 12%]
# [Epoch 956,0] [D loss: 0.052602, D acc:  98%] [G loss: 4.855577][well error: 15%]
# [Epoch 956,0] [D loss: 0.010225, D acc: 100%] [G loss: 8.014938][well error: 22%]
# [Epoch 956,0] [D loss: 0.045020, D acc:  99%] [G loss: 7.647840][well error:  8%]
# [Epoch 956,0] [D loss: 0.018420, D acc:  99%] [G loss: 7.140490][well error: 13%]
# [Epoch 956,0] [D loss: 0.117881, D acc:  97%] [G loss: 3.715476][well error: 13%]
# [Epoch 956,0] [D loss: 0.082424, D acc:  98%] [G loss: 6.765463][well error: 11%]
# [Epoch 956,0] [D loss: 0.055285, D acc:  98%] [G loss: 12.017248][well error: 13%]
# [Epoch 956,0] [D loss: 0.002460, D acc: 100%] [G loss: 11.677842][well error: 16%]
# [Epoch 956,0] [D loss: 0.018614, D acc:  99%] [G loss: 5.272302][well error: 16%]
# [Epoch 956,0] [D loss: 0.004850, D acc: 100%] [G loss: 10.197918][well error: 15%]
# [Epoch 956,0] [D loss: 0.507951, D acc:  76%] [G loss: 8.206347][well error: 13%]
# [Epoch 956,0] [D loss: 0.071439, D acc:  97%] [G loss: 5.393457][well error: 15%]
# [Epoch 956,0] [D loss: 0.086169, D acc:  97%] [G loss: 3.734216][well error: 12%]
# [Epoch 956,1] [D loss: 0.077353, D acc:  97%] [G loss: 6.280168][well error: 16%]
# [Epoch 956,1] [D loss: 0.017832, D acc:  99%] [G loss: 9.940220][well error: 10%]
# [Epoch 956,1] [D loss: 0.030188, D acc:  99%] [G loss: 7.185355][well error: 15%]
# [Epoch 956,1] [D loss: 0.007119, D acc:  99%] [G loss: 9.640196][well error: 10%]
# [Epoch 956,1] [D loss: 0.016030, D acc:  99%] [G loss: 9.225327][well error: 17%]
# [Epoch 956,1] [D loss: 0.013076, D acc:  99%] [G loss: 10.000243][well error: 19%]
# [Epoch 956,1] [D loss: 0.042288, D acc:  99%] [G loss: 9.112723][well error: 15%]
# [Epoch 956,1] [D loss: 0.046328, D acc:  98%] [G loss: 6.558359][well error: 13%]
# [Epoch 956,1] [D loss: 0.095516, D acc:  96%] [G loss: 10.053708][well error: 12%]
# [Epoch 956,1] [D loss: 0.056384, D acc:  99%] [G loss: 5.445954][well error: 13%]
# [Epoch 956,1] [D loss: 0.011081, D acc:  99%] [G loss: 10.838482][well error: 16%]
# [Epoch 956,1] [D loss: 0.075331, D acc:  98%] [G loss: 7.914059][well error: 15%]
# [Epoch 956,1] [D loss: 0.025830, D acc:  99%] [G loss: 8.227984][well error: 13%]
# [Epoch 956,1] [D loss: 0.014700, D acc:  99%] [G loss: 8.144111][well error: 11%]
# [Epoch 956,1] [D loss: 0.007748, D acc: 100%] [G loss: 10.012837][well error: 16%]
# [Epoch 956,1] [D loss: 0.012979, D acc: 100%] [G loss: 5.888928][well error: 16%]
# [Epoch 956,1] [D loss: 0.020211, D acc:  99%] [G loss: 10.710663][well error: 11%]
# [Epoch 956,1] [D loss: 0.025074, D acc:  99%] [G loss: 7.048576][well error: 13%]
# [Epoch 956,1] [D loss: 0.013093, D acc: 100%] [G loss: 5.028065][well error:  6%]
# [Epoch 956,1] [D loss: 0.081884, D acc:  98%] [G loss: 6.248420][well error: 15%]
# [Epoch 956,1] [D loss: 0.028420, D acc:  99%] [G loss: 9.437469][well error: 14%]
# [Epoch 956,2] [D loss: 0.101559, D acc:  98%] [G loss: 5.541481][well error: 14%]
# [Epoch 956,2] [D loss: 0.046636, D acc:  99%] [G loss: 6.780344][well error: 16%]
# [Epoch 956,2] [D loss: 0.012616, D acc:  99%] [G loss: 6.302857][well error: 15%]
# [Epoch 956,2] [D loss: 0.014704, D acc:  99%] [G loss: 11.445514][well error: 14%]
# [Epoch 956,2] [D loss: 0.032902, D acc:  99%] [G loss: 9.156538][well error: 16%]
# [Epoch 956,2] [D loss: 0.009289, D acc:  99%] [G loss: 9.860653][well error: 12%]
# [Epoch 956,2] [D loss: 0.012106, D acc: 100%] [G loss: 9.122355][well error: 14%]
# [Epoch 956,2] [D loss: 0.026929, D acc:  99%] [G loss: 8.544938][well error: 18%]
# [Epoch 956,2] [D loss: 0.008929, D acc: 100%] [G loss: 6.500464][well error: 14%]
# [Epoch 956,2] [D loss: 0.025601, D acc:  99%] [G loss: 6.773579][well error: 18%]
# [Epoch 956,2] [D loss: 0.010258, D acc:  99%] [G loss: 6.421484][well error: 15%]
# [Epoch 956,2] [D loss: 0.210567, D acc:  90%] [G loss: 3.927407][well error: 14%]
# [Epoch 956,2] [D loss: 0.181571, D acc:  93%] [G loss: 7.616887][well error: 10%]
# [Epoch 956,2] [D loss: 0.011537, D acc:  99%] [G loss: 9.127929][well error: 16%]
# [Epoch 956,2] [D loss: 0.049173, D acc:  99%] [G loss: 8.600901][well error: 20%]
# [Epoch 956,2] [D loss: 0.172857, D acc:  93%] [G loss: 3.371283][well error: 14%]
# [Epoch 956,2] [D loss: 0.016605, D acc:  99%] [G loss: 9.682275][well error: 16%]
# [Epoch 956,2] [D loss: 0.022410, D acc:  99%] [G loss: 7.404895][well error: 12%]
# [Epoch 956,2] [D loss: 0.010284, D acc: 100%] [G loss: 12.704701][well error: 13%]
# [Epoch 956,2] [D loss: 0.240540, D acc:  89%] [G loss: 12.483528][well error: 19%]
# [Epoch 956,2] [D loss: 0.017238, D acc:  99%] [G loss: 6.713127][well error: 14%]
# [Epoch 956,3] [D loss: 0.051872, D acc:  98%] [G loss: 4.842009][well error: 15%]
# [Epoch 956,3] [D loss: 0.057915, D acc:  99%] [G loss: 4.724063][well error: 18%]
# [Epoch 956,3] [D loss: 0.047761, D acc:  99%] [G loss: 9.058144][well error: 17%]
# [Epoch 956,3] [D loss: 0.112107, D acc:  94%] [G loss: 13.309034][well error: 15%]
# [Epoch 956,3] [D loss: 0.054111, D acc:  98%] [G loss: 6.932394][well error: 16%]
# [Epoch 956,3] [D loss: 0.025897, D acc:  99%] [G loss: 4.240921][well error:  9%]
# [Epoch 956,3] [D loss: 0.078798, D acc:  98%] [G loss: 6.697005][well error: 15%]
# [Epoch 956,3] [D loss: 0.034564, D acc:  99%] [G loss: 7.690051][well error: 13%]
# [Epoch 956,3] [D loss: 0.192017, D acc:  91%] [G loss: 5.618714][well error: 15%]
# [Epoch 956,3] [D loss: 0.092708, D acc:  97%] [G loss: 5.990666][well error: 20%]
# [Epoch 956,3] [D loss: 0.184521, D acc:  91%] [G loss: 5.560205][well error: 18%]
# [Epoch 956,3] [D loss: 0.046788, D acc:  98%] [G loss: 9.228547][well error: 12%]
# [Epoch 956,3] [D loss: 0.213741, D acc:  88%] [G loss: 8.564808][well error: 16%]
# [Epoch 956,3] [D loss: 0.096542, D acc:  96%] [G loss: 3.373688][well error: 14%]
# [Epoch 956,3] [D loss: 0.016330, D acc: 100%] [G loss: 8.646339][well error: 14%]
# [Epoch 956,3] [D loss: 0.238230, D acc:  88%] [G loss: 11.035222][well error: 10%]
# [Epoch 956,3] [D loss: 0.038703, D acc:  99%] [G loss: 6.167239][well error: 17%]
# [Epoch 956,3] [D loss: 0.010376, D acc:  99%] [G loss: 7.564968][well error: 16%]
# [Epoch 956,3] [D loss: 0.009126, D acc: 100%] [G loss: 7.474775][well error: 16%]
# [Epoch 956,3] [D loss: 0.017835, D acc:  99%] [G loss: 14.120412][well error: 17%]
# [Epoch 956,3] [D loss: 0.036779, D acc:  99%] [G loss: 5.685642][well error: 20%]
# [Epoch 956,4] [D loss: 0.018662, D acc:  99%] [G loss: 10.424771][well error: 16%]
# [Epoch 956,4] [D loss: 0.015681, D acc: 100%] [G loss: 6.963552][well error: 22%]
# [Epoch 956,4] [D loss: 0.067916, D acc:  96%] [G loss: 5.576000][well error: 19%]
# [Epoch 956,4] [D loss: 0.111168, D acc:  96%] [G loss: 8.117064][well error: 11%]
# [Epoch 956,4] [D loss: 0.016018, D acc:  99%] [G loss: 4.967694][well error: 13%]
# [Epoch 956,4] [D loss: 0.040507, D acc:  99%] [G loss: 6.435057][well error: 13%]
# [Epoch 956,4] [D loss: 0.029484, D acc:  99%] [G loss: 8.578938][well error: 20%]
# [Epoch 956,4] [D loss: 0.305237, D acc:  85%] [G loss: 4.870304][well error: 15%]
# [Epoch 956,4] [D loss: 0.059974, D acc:  98%] [G loss: 6.646521][well error: 19%]
# [Epoch 956,4] [D loss: 0.053871, D acc:  99%] [G loss: 4.132149][well error: 10%]
# [Epoch 956,4] [D loss: 0.037320, D acc:  99%] [G loss: 10.679893][well error: 18%]
# [Epoch 956,4] [D loss: 0.214710, D acc:  92%] [G loss: 1.346508][well error: 13%]
# [Epoch 956,4] [D loss: 0.017626, D acc:  99%] [G loss: 7.354415][well error: 13%]
# [Epoch 956,4] [D loss: 0.007401, D acc: 100%] [G loss: 10.164140][well error: 19%]
# [Epoch 956,4] [D loss: 0.007072, D acc: 100%] [G loss: 10.911435][well error: 16%]
# [Epoch 956,4] [D loss: 0.012217, D acc:  99%] [G loss: 6.689439][well error: 11%]
# [Epoch 956,4] [D loss: 0.067672, D acc:  98%] [G loss: 5.775524][well error: 18%]
# [Epoch 956,4] [D loss: 0.007141, D acc: 100%] [G loss: 7.433513][well error: 12%]
# [Epoch 956,4] [D loss: 0.107497, D acc:  96%] [G loss: 9.372737][well error: 16%]
# [Epoch 956,4] [D loss: 0.039017, D acc:  99%] [G loss: 8.743716][well error: 18%]
# [Epoch 956,4] [D loss: 0.102757, D acc:  93%] [G loss: 7.481176][well error: 10%]
# [Epoch 957,0] [D loss: 0.025255, D acc:  99%] [G loss: 9.276434][well error: 13%]
# [Epoch 957,0] [D loss: 0.052783, D acc:  98%] [G loss: 11.783190][well error:  7%]
# [Epoch 957,0] [D loss: 0.043784, D acc:  99%] [G loss: 5.967142][well error: 15%]
# [Epoch 957,0] [D loss: 0.117830, D acc:  95%] [G loss: 9.205896][well error: 15%]
# [Epoch 957,0] [D loss: 0.032015, D acc:  99%] [G loss: 6.999193][well error: 17%]
# [Epoch 957,0] [D loss: 0.786888, D acc:  69%] [G loss: 6.935255][well error: 16%]
# [Epoch 957,0] [D loss: 0.166213, D acc:  94%] [G loss: 2.657427][well error: 12%]
# [Epoch 957,0] [D loss: 0.036112, D acc:  99%] [G loss: 11.173514][well error: 18%]
# [Epoch 957,0] [D loss: 0.154821, D acc:  94%] [G loss: 9.899746][well error: 14%]
# [Epoch 957,0] [D loss: 0.123491, D acc:  96%] [G loss: 5.598668][well error: 12%]
# [Epoch 957,0] [D loss: 0.031084, D acc:  99%] [G loss: 6.465837][well error: 15%]
# [Epoch 957,0] [D loss: 0.014011, D acc:  99%] [G loss: 12.255070][well error: 16%]
# [Epoch 957,0] [D loss: 0.015143, D acc:  99%] [G loss: 6.384678][well error: 16%]
# [Epoch 957,0] [D loss: 0.079182, D acc:  98%] [G loss: 2.741574][well error: 17%]
# [Epoch 957,0] [D loss: 0.012514, D acc: 100%] [G loss: 7.498728][well error: 15%]
# [Epoch 957,0] [D loss: 0.032684, D acc:  99%] [G loss: 11.661053][well error: 15%]
# [Epoch 957,0] [D loss: 0.076863, D acc:  98%] [G loss: 6.194981][well error: 11%]
# [Epoch 957,0] [D loss: 0.008506, D acc: 100%] [G loss: 9.797252][well error: 11%]
# [Epoch 957,0] [D loss: 0.261370, D acc:  89%] [G loss: 11.109561][well error: 11%]
# [Epoch 957,0] [D loss: 0.168822, D acc:  93%] [G loss: 5.196712][well error: 15%]
# [Epoch 957,0] [D loss: 0.011392, D acc:  99%] [G loss: 9.283471][well error: 13%]
# [Epoch 957,1] [D loss: 0.047304, D acc:  98%] [G loss: 5.333862][well error: 13%]
# [Epoch 957,1] [D loss: 0.005463, D acc: 100%] [G loss: 10.454214][well error: 14%]
# [Epoch 957,1] [D loss: 0.035838, D acc:  99%] [G loss: 11.998650][well error: 15%]
# [Epoch 957,1] [D loss: 0.057128, D acc:  98%] [G loss: 6.890307][well error: 16%]
# [Epoch 957,1] [D loss: 0.008373, D acc: 100%] [G loss: 8.627979][well error: 16%]
# [Epoch 957,1] [D loss: 0.047848, D acc:  99%] [G loss: 6.482108][well error: 18%]
# [Epoch 957,1] [D loss: 0.072496, D acc:  98%] [G loss: 4.420088][well error: 18%]
# [Epoch 957,1] [D loss: 0.028991, D acc:  99%] [G loss: 10.593975][well error: 11%]
# [Epoch 957,1] [D loss: 0.063860, D acc:  98%] [G loss: 6.629127][well error: 18%]
# [Epoch 957,1] [D loss: 0.418001, D acc:  83%] [G loss: 2.405964][well error: 14%]
# [Epoch 957,1] [D loss: 0.018317, D acc:  99%] [G loss: 10.809863][well error: 12%]
# [Epoch 957,1] [D loss: 0.024032, D acc:  99%] [G loss: 5.799480][well error: 13%]
# [Epoch 957,1] [D loss: 0.008700, D acc:  99%] [G loss: 14.116690][well error: 12%]
# [Epoch 957,1] [D loss: 0.012653, D acc:  99%] [G loss: 8.400087][well error: 13%]
# [Epoch 957,1] [D loss: 0.271594, D acc:  88%] [G loss: 6.000623][well error: 20%]
# [Epoch 957,1] [D loss: 0.012426, D acc: 100%] [G loss: 10.839638][well error: 15%]
# [Epoch 957,1] [D loss: 0.169519, D acc:  92%] [G loss: 11.327035][well error: 23%]
# [Epoch 957,1] [D loss: 0.049494, D acc:  98%] [G loss: 12.049022][well error: 14%]
# [Epoch 957,1] [D loss: 0.318438, D acc:  87%] [G loss: 10.081514][well error: 13%]
# [Epoch 957,1] [D loss: 0.281749, D acc:  87%] [G loss: 4.547181][well error: 13%]
# [Epoch 957,1] [D loss: 0.020745, D acc:  99%] [G loss: 10.058351][well error: 16%]
# [Epoch 957,2] [D loss: 0.047801, D acc:  98%] [G loss: 10.029180][well error: 17%]
# [Epoch 957,2] [D loss: 0.054884, D acc:  99%] [G loss: 10.649295][well error: 14%]
# [Epoch 957,2] [D loss: 0.172877, D acc:  91%] [G loss: 6.582309][well error: 18%]
# [Epoch 957,2] [D loss: 0.023430, D acc:  99%] [G loss: 6.651542][well error: 13%]
# [Epoch 957,2] [D loss: 0.040326, D acc:  99%] [G loss: 10.396101][well error:  9%]
# [Epoch 957,2] [D loss: 0.019347, D acc:  99%] [G loss: 10.343148][well error: 13%]
# [Epoch 957,2] [D loss: 0.083646, D acc:  96%] [G loss: 6.944016][well error: 12%]
# [Epoch 957,2] [D loss: 0.008631, D acc:  99%] [G loss: 10.047998][well error: 20%]
# [Epoch 957,2] [D loss: 0.041881, D acc:  99%] [G loss: 6.852123][well error: 16%]
# [Epoch 957,2] [D loss: 0.028826, D acc:  99%] [G loss: 7.611160][well error: 12%]
# [Epoch 957,2] [D loss: 0.090544, D acc:  95%] [G loss: 6.122712][well error: 20%]
# [Epoch 957,2] [D loss: 0.013370, D acc:  99%] [G loss: 4.456325][well error: 10%]
# [Epoch 957,2] [D loss: 0.015664, D acc:  99%] [G loss: 12.118309][well error: 16%]
# [Epoch 957,2] [D loss: 0.341291, D acc:  83%] [G loss: 8.644423][well error: 17%]
# [Epoch 957,2] [D loss: 0.501373, D acc:  76%] [G loss: 3.008012][well error: 12%]
# [Epoch 957,2] [D loss: 0.034149, D acc:  99%] [G loss: 8.493557][well error: 17%]
# [Epoch 957,2] [D loss: 0.032888, D acc:  99%] [G loss: 12.657324][well error: 12%]
# [Epoch 957,2] [D loss: 0.144429, D acc:  94%] [G loss: 9.848986][well error: 17%]
# [Epoch 957,2] [D loss: 0.016520, D acc:  99%] [G loss: 5.816592][well error: 14%]
# [Epoch 957,2] [D loss: 0.295882, D acc:  85%] [G loss: 6.459529][well error: 14%]
# [Epoch 957,2] [D loss: 0.019607, D acc:  99%] [G loss: 9.638036][well error: 12%]
# [Epoch 957,3] [D loss: 0.022093, D acc:  99%] [G loss: 13.247475][well error: 15%]
# [Epoch 957,3] [D loss: 0.012024, D acc:  99%] [G loss: 10.800222][well error: 16%]
# [Epoch 957,3] [D loss: 0.055905, D acc:  97%] [G loss: 5.778986][well error: 16%]
# [Epoch 957,3] [D loss: 0.027074, D acc:  99%] [G loss: 5.329632][well error: 15%]
# [Epoch 957,3] [D loss: 0.174101, D acc:  93%] [G loss: 6.234828][well error: 15%]
# [Epoch 957,3] [D loss: 0.007052, D acc:  99%] [G loss: 8.720345][well error: 12%]
# [Epoch 957,3] [D loss: 0.121993, D acc:  95%] [G loss: 10.905422][well error: 17%]
# [Epoch 957,3] [D loss: 0.053317, D acc:  98%] [G loss: 7.066616][well error: 19%]
# [Epoch 957,3] [D loss: 0.029965, D acc:  99%] [G loss: 5.150249][well error:  8%]
# [Epoch 957,3] [D loss: 0.027572, D acc:  99%] [G loss: 7.750196][well error: 18%]
# [Epoch 957,3] [D loss: 0.040130, D acc:  99%] [G loss: 8.906181][well error: 14%]
# [Epoch 957,3] [D loss: 0.012415, D acc:  99%] [G loss: 8.471165][well error: 11%]
# [Epoch 957,3] [D loss: 0.091696, D acc:  96%] [G loss: 9.224755][well error: 15%]
# [Epoch 957,3] [D loss: 0.006597, D acc: 100%] [G loss: 12.791728][well error: 12%]
# [Epoch 957,3] [D loss: 0.026357, D acc:  99%] [G loss: 7.050879][well error: 12%]
# [Epoch 957,3] [D loss: 0.022957, D acc: 100%] [G loss: 10.918640][well error: 17%]
# [Epoch 957,3] [D loss: 0.046039, D acc:  99%] [G loss: 8.113465][well error: 17%]
# [Epoch 957,3] [D loss: 0.054028, D acc:  99%] [G loss: 9.791128][well error: 13%]
# [Epoch 957,3] [D loss: 0.055959, D acc:  97%] [G loss: 10.917992][well error: 17%]
# [Epoch 957,3] [D loss: 0.006140, D acc:  99%] [G loss: 11.271165][well error: 18%]
# [Epoch 957,3] [D loss: 0.005179, D acc: 100%] [G loss: 9.759143][well error: 13%]
# ...
# [Epoch 998,0] [D loss: 0.032674, D acc:  99%] [G loss: 7.532155][well error: 14%]
# [Epoch 998,0] [D loss: 0.504167, D acc:  78%] [G loss: 5.823848][well error: 17%]
# [Epoch 998,0] [D loss: 0.047574, D acc:  99%] [G loss: 8.717705][well error: 16%]
# [Epoch 998,1] [D loss: 0.007229, D acc: 100%] [G loss: 12.649547][well error: 16%]
# [Epoch 998,1] [D loss: 0.172039, D acc:  93%] [G loss: 8.683597][well error: 15%]
# [Epoch 998,1] [D loss: 0.296141, D acc:  86%] [G loss: 5.607464][well error: 21%]
# [Epoch 998,1] [D loss: 0.017628, D acc:  99%] [G loss: 7.857165][well error: 20%]
# [Epoch 998,1] [D loss: 0.090021, D acc:  97%] [G loss: 3.890333][well error: 21%]
# [Epoch 998,1] [D loss: 0.015350, D acc:  99%] [G loss: 7.500587][well error: 14%]
# [Epoch 998,1] [D loss: 0.007485, D acc: 100%] [G loss: 10.310304][well error: 22%]
# [Epoch 998,1] [D loss: 0.011293, D acc:  99%] [G loss: 9.909183][well error: 21%]
# [Epoch 998,1] [D loss: 0.015806, D acc:  99%] [G loss: 10.817286][well error: 15%]
# [Epoch 998,1] [D loss: 0.032408, D acc:  99%] [G loss: 4.324272][well error: 14%]
# [Epoch 998,1] [D loss: 0.023167, D acc:  99%] [G loss: 8.993687][well error: 16%]
# [Epoch 998,1] [D loss: 0.027567, D acc:  99%] [G loss: 8.422196][well error: 13%]
# [Epoch 998,1] [D loss: 0.038533, D acc:  99%] [G loss: 5.066992][well error: 14%]
# [Epoch 998,1] [D loss: 0.080938, D acc:  98%] [G loss: 6.244827][well error: 15%]
# [Epoch 998,1] [D loss: 0.043258, D acc:  98%] [G loss: 7.017910][well error: 15%]
# [Epoch 998,1] [D loss: 0.010330, D acc: 100%] [G loss: 9.493419][well error: 18%]
# [Epoch 998,1] [D loss: 0.042008, D acc:  99%] [G loss: 4.886873][well error: 18%]
# [Epoch 998,1] [D loss: 0.071277, D acc:  98%] [G loss: 5.498259][well error: 20%]
# [Epoch 998,1] [D loss: 0.013388, D acc:  99%] [G loss: 10.723285][well error: 25%]
# [Epoch 998,1] [D loss: 0.018597, D acc:  99%] [G loss: 10.776693][well error: 11%]
# [Epoch 998,1] [D loss: 0.011773, D acc: 100%] [G loss: 12.015646][well error: 15%]
# [Epoch 998,2] [D loss: 0.033588, D acc:  99%] [G loss: 6.477646][well error: 15%]
# [Epoch 998,2] [D loss: 0.028841, D acc:  99%] [G loss: 8.811428][well error: 18%]
# [Epoch 998,2] [D loss: 0.014254, D acc: 100%] [G loss: 11.900703][well error: 17%]
# [Epoch 998,2] [D loss: 0.064407, D acc:  98%] [G loss: 9.552648][well error: 27%]
# [Epoch 998,2] [D loss: 0.028142, D acc:  99%] [G loss: 6.657393][well error: 17%]
# [Epoch 998,2] [D loss: 0.043629, D acc:  99%] [G loss: 7.639073][well error: 21%]
# [Epoch 998,2] [D loss: 0.043985, D acc:  99%] [G loss: 5.985808][well error: 16%]
# [Epoch 998,2] [D loss: 0.104519, D acc:  96%] [G loss: 10.376672][well error: 18%]
# [Epoch 998,2] [D loss: 0.525604, D acc:  78%] [G loss: 9.382351][well error: 22%]
# [Epoch 998,2] [D loss: 0.281330, D acc:  87%] [G loss: 7.020135][well error: 23%]
# [Epoch 998,2] [D loss: 0.034128, D acc:  99%] [G loss: 10.736124][well error: 20%]
# [Epoch 998,2] [D loss: 0.105079, D acc:  96%] [G loss: 8.050501][well error: 17%]
# [Epoch 998,2] [D loss: 0.127123, D acc:  96%] [G loss: 6.097301][well error: 22%]
# [Epoch 998,2] [D loss: 0.044222, D acc:  99%] [G loss: 8.545154][well error: 23%]
# [Epoch 998,2] [D loss: 0.022845, D acc:  99%] [G loss: 10.931127][well error: 16%]
# [Epoch 998,2] [D loss: 0.340093, D acc:  87%] [G loss: 4.679140][well error: 18%]
# [Epoch 998,2] [D loss: 0.604946, D acc:  72%] [G loss: 4.676435][well error: 21%]
# [Epoch 998,2] [D loss: 0.011818, D acc: 100%] [G loss: 7.625139][well error: 14%]
# [Epoch 998,2] [D loss: 0.488019, D acc:  80%] [G loss: 8.404800][well error: 20%]
# [Epoch 998,2] [D loss: 0.012057, D acc:  99%] [G loss: 6.090123][well error: 13%]
# [Epoch 998,2] [D loss: 0.190103, D acc:  93%] [G loss: 5.629082][well error: 21%]
# [Epoch 998,3] [D loss: 0.193244, D acc:  91%] [G loss: 8.830162][well error: 16%]
# [Epoch 998,3] [D loss: 0.085359, D acc:  97%] [G loss: 11.683624][well error: 15%]
# [Epoch 998,3] [D loss: 0.041153, D acc:  99%] [G loss: 7.870516][well error: 15%]
# [Epoch 998,3] [D loss: 0.117600, D acc:  96%] [G loss: 6.351514][well error: 16%]
# [Epoch 998,3] [D loss: 0.049182, D acc:  97%] [G loss: 12.093214][well error: 20%]
# [Epoch 998,3] [D loss: 0.071265, D acc:  98%] [G loss: 7.244928][well error: 16%]
# [Epoch 998,3] [D loss: 0.020842, D acc:  99%] [G loss: 7.781286][well error: 19%]
# [Epoch 998,3] [D loss: 0.034674, D acc:  99%] [G loss: 9.286438][well error: 20%]
# [Epoch 998,3] [D loss: 0.020136, D acc:  99%] [G loss: 9.064773][well error: 23%]
# [Epoch 998,3] [D loss: 0.027503, D acc:  99%] [G loss: 4.449967][well error: 18%]
# [Epoch 998,3] [D loss: 0.012402, D acc:  99%] [G loss: 9.051325][well error: 18%]
# [Epoch 998,3] [D loss: 0.078241, D acc:  97%] [G loss: 8.473934][well error: 23%]
# [Epoch 998,3] [D loss: 0.066376, D acc:  98%] [G loss: 6.338772][well error: 25%]
# [Epoch 998,3] [D loss: 0.110619, D acc:  96%] [G loss: 5.376275][well error: 18%]
# [Epoch 998,3] [D loss: 0.018297, D acc:  99%] [G loss: 10.777251][well error: 18%]
# [Epoch 998,3] [D loss: 0.137829, D acc:  94%] [G loss: 10.475792][well error: 13%]
# [Epoch 998,3] [D loss: 0.062251, D acc:  98%] [G loss: 2.842472][well error: 14%]
# [Epoch 998,3] [D loss: 0.030820, D acc:  99%] [G loss: 5.503026][well error: 18%]
# [Epoch 998,3] [D loss: 0.037775, D acc:  99%] [G loss: 8.312856][well error: 22%]
# [Epoch 998,3] [D loss: 0.004549, D acc: 100%] [G loss: 8.008845][well error: 20%]
# [Epoch 998,3] [D loss: 0.020441, D acc:  99%] [G loss: 8.888453][well error: 18%]
# [Epoch 998,4] [D loss: 0.032780, D acc:  99%] [G loss: 4.868346][well error: 19%]
# [Epoch 998,4] [D loss: 0.034644, D acc:  99%] [G loss: 6.907739][well error: 15%]
# [Epoch 998,4] [D loss: 0.043632, D acc:  99%] [G loss: 8.264190][well error: 20%]
# [Epoch 998,4] [D loss: 0.133294, D acc:  94%] [G loss: 8.648680][well error: 13%]
# [Epoch 998,4] [D loss: 0.003604, D acc: 100%] [G loss: 9.242937][well error: 14%]
# [Epoch 998,4] [D loss: 0.081207, D acc:  97%] [G loss: 6.882723][well error: 17%]
# [Epoch 998,4] [D loss: 0.010243, D acc: 100%] [G loss: 8.580661][well error: 15%]
# [Epoch 998,4] [D loss: 0.333016, D acc:  82%] [G loss: 6.850894][well error: 16%]
# [Epoch 998,4] [D loss: 0.075024, D acc:  97%] [G loss: 9.970799][well error: 15%]
# [Epoch 998,4] [D loss: 0.031141, D acc:  99%] [G loss: 6.213047][well error: 17%]
# [Epoch 998,4] [D loss: 0.017988, D acc:  99%] [G loss: 6.606383][well error: 16%]
# [Epoch 998,4] [D loss: 0.034134, D acc:  99%] [G loss: 6.348056][well error: 16%]
# [Epoch 998,4] [D loss: 0.005520, D acc: 100%] [G loss: 5.384446][well error: 22%]
# [Epoch 998,4] [D loss: 0.014750, D acc: 100%] [G loss: 8.671653][well error: 16%]
# [Epoch 998,4] [D loss: 0.015345, D acc:  99%] [G loss: 9.644470][well error: 16%]
# [Epoch 998,4] [D loss: 0.155646, D acc:  93%] [G loss: 7.930080][well error: 15%]
# [Epoch 998,4] [D loss: 0.083852, D acc:  96%] [G loss: 8.099984][well error: 22%]
# [Epoch 998,4] [D loss: 0.178989, D acc:  94%] [G loss: 4.012919][well error: 20%]
# [Epoch 998,4] [D loss: 0.031430, D acc:  99%] [G loss: 9.796231][well error: 17%]
# [Epoch 998,4] [D loss: 0.028257, D acc:  99%] [G loss: 6.457404][well error: 20%]
# [Epoch 998,4] [D loss: 0.197390, D acc:  91%] [G loss: 4.765532][well error: 24%]
# [Epoch 999,0] [D loss: 0.028886, D acc:  99%] [G loss: 6.221123][well error: 18%]
# [Epoch 999,0] [D loss: 0.040911, D acc:  98%] [G loss: 11.877359][well error: 20%]
# [Epoch 999,0] [D loss: 0.109917, D acc:  97%] [G loss: 6.441710][well error: 11%]
# [Epoch 999,0] [D loss: 0.009734, D acc:  99%] [G loss: 9.674664][well error: 21%]
# [Epoch 999,0] [D loss: 0.047626, D acc:  98%] [G loss: 5.021024][well error: 21%]
# [Epoch 999,0] [D loss: 0.038100, D acc:  99%] [G loss: 4.274460][well error: 19%]
# [Epoch 999,0] [D loss: 0.023018, D acc:  99%] [G loss: 9.265079][well error: 18%]
# [Epoch 999,0] [D loss: 0.025734, D acc:  99%] [G loss: 6.699362][well error: 16%]
# [Epoch 999,0] [D loss: 0.009549, D acc:  99%] [G loss: 9.844181][well error: 13%]
# [Epoch 999,0] [D loss: 0.031236, D acc:  99%] [G loss: 5.392466][well error: 17%]
# [Epoch 999,0] [D loss: 0.060619, D acc:  98%] [G loss: 8.008072][well error: 21%]
# [Epoch 999,0] [D loss: 0.101901, D acc:  96%] [G loss: 3.222260][well error: 21%]
# [Epoch 999,0] [D loss: 0.452108, D acc:  80%] [G loss: 7.417999][well error: 23%]
# [Epoch 999,0] [D loss: 0.020292, D acc:  99%] [G loss: 9.892510][well error: 16%]
# [Epoch 999,0] [D loss: 0.058356, D acc:  97%] [G loss: 9.206198][well error: 17%]
# [Epoch 999,0] [D loss: 0.141182, D acc:  94%] [G loss: 6.285636][well error: 12%]
# [Epoch 999,0] [D loss: 0.021539, D acc:  99%] [G loss: 7.680707][well error: 20%]
# [Epoch 999,0] [D loss: 0.007485, D acc:  99%] [G loss: 6.475027][well error: 14%]
# [Epoch 999,0] [D loss: 0.010653, D acc:  99%] [G loss: 6.957304][well error: 13%]
# [Epoch 999,0] [D loss: 0.006801, D acc: 100%] [G loss: 7.662148][well error: 19%]
# [Epoch 999,0] [D loss: 0.031785, D acc:  99%] [G loss: 11.021596][well error: 17%]
# [Epoch 999,1] [D loss: 0.060314, D acc:  98%] [G loss: 5.083561][well error: 20%]
# [Epoch 999,1] [D loss: 0.010342, D acc:  99%] [G loss: 8.591499][well error: 15%]
# [Epoch 999,1] [D loss: 0.003009, D acc: 100%] [G loss: 12.269787][well error: 15%]
# [Epoch 999,1] [D loss: 0.064074, D acc:  98%] [G loss: 5.202356][well error: 13%]
# [Epoch 999,1] [D loss: 0.035138, D acc:  99%] [G loss: 10.197788][well error: 20%]
# [Epoch 999,1] [D loss: 0.123347, D acc:  96%] [G loss: 7.352746][well error: 23%]
# [Epoch 999,1] [D loss: 0.020441, D acc:  99%] [G loss: 11.516657][well error: 16%]
# [Epoch 999,1] [D loss: 0.223073, D acc:  90%] [G loss: 11.752413][well error: 18%]
# [Epoch 999,1] [D loss: 0.014399, D acc:  99%] [G loss: 6.588514][well error: 20%]
# [Epoch 999,1] [D loss: 0.044971, D acc:  99%] [G loss: 6.859309][well error: 17%]
# [Epoch 999,1] [D loss: 0.111057, D acc:  96%] [G loss: 6.353642][well error: 16%]
# [Epoch 999,1] [D loss: 0.189764, D acc:  92%] [G loss: 7.476428][well error: 13%]
# [Epoch 999,1] [D loss: 0.048923, D acc:  99%] [G loss: 4.468619][well error: 13%]
# [Epoch 999,1] [D loss: 0.005857, D acc:  99%] [G loss: 7.132715][well error: 21%]
# [Epoch 999,1] [D loss: 0.026113, D acc:  99%] [G loss: 6.736674][well error: 17%]
# [Epoch 999,1] [D loss: 0.108842, D acc:  95%] [G loss: 6.225880][well error: 15%]
# [Epoch 999,1] [D loss: 0.052915, D acc:  98%] [G loss: 8.046924][well error: 17%]
# [Epoch 999,1] [D loss: 0.028985, D acc:  99%] [G loss: 8.440525][well error: 14%]
# [Epoch 999,1] [D loss: 0.047284, D acc:  99%] [G loss: 6.716942][well error: 20%]
# [Epoch 999,1] [D loss: 0.060421, D acc:  99%] [G loss: 7.878560][well error: 15%]
# [Epoch 999,1] [D loss: 0.012111, D acc: 100%] [G loss: 6.499568][well error: 18%]
# [Epoch 999,2] [D loss: 0.018293, D acc:  99%] [G loss: 10.485311][well error: 15%]
# [Epoch 999,2] [D loss: 0.057852, D acc:  98%] [G loss: 15.089685][well error: 16%]
# [Epoch 999,2] [D loss: 0.169239, D acc:  93%] [G loss: 4.800589][well error: 19%]
# [Epoch 999,2] [D loss: 0.020496, D acc:  99%] [G loss: 6.872838][well error: 18%]
# [Epoch 999,2] [D loss: 0.004617, D acc: 100%] [G loss: 8.190944][well error: 18%]
# [Epoch 999,2] [D loss: 0.051367, D acc:  98%] [G loss: 9.255239][well error: 13%]
# [Epoch 999,2] [D loss: 0.026129, D acc:  99%] [G loss: 6.658686][well error: 18%]
# [Epoch 999,2] [D loss: 0.005033, D acc:  99%] [G loss: 11.807323][well error: 10%]
# [Epoch 999,2] [D loss: 0.019792, D acc:  99%] [G loss: 9.114052][well error: 16%]
# [Epoch 999,2] [D loss: 0.006947, D acc:  99%] [G loss: 7.946414][well error: 15%]
# [Epoch 999,2] [D loss: 0.015324, D acc:  99%] [G loss: 8.350620][well error: 11%]
# [Epoch 999,2] [D loss: 0.016532, D acc:  99%] [G loss: 12.735092][well error: 20%]
# [Epoch 999,2] [D loss: 0.086538, D acc:  98%] [G loss: 8.840658][well error: 19%]
# [Epoch 999,2] [D loss: 0.055111, D acc:  98%] [G loss: 3.905716][well error: 11%]
# [Epoch 999,2] [D loss: 0.002240, D acc:  99%] [G loss: 12.782924][well error: 16%]
# [Epoch 999,2] [D loss: 0.015810, D acc:  99%] [G loss: 8.158822][well error: 21%]
# [Epoch 999,2] [D loss: 0.067983, D acc:  98%] [G loss: 12.607912][well error: 21%]
# [Epoch 999,2] [D loss: 0.041668, D acc:  98%] [G loss: 5.232110][well error: 13%]
# [Epoch 999,2] [D loss: 0.072500, D acc:  97%] [G loss: 5.526841][well error: 17%]
# [Epoch 999,2] [D loss: 0.013818, D acc:  99%] [G loss: 10.599936][well error: 19%]
# [Epoch 999,2] [D loss: 0.168725, D acc:  92%] [G loss: 6.440125][well error: 13%]
# [Epoch 999,3] [D loss: 0.049309, D acc:  99%] [G loss: 6.402043][well error: 18%]
# [Epoch 999,3] [D loss: 0.010961, D acc: 100%] [G loss: 10.140816][well error: 20%]
# [Epoch 999,3] [D loss: 0.019551, D acc:  99%] [G loss: 8.703150][well error: 19%]
# [Epoch 999,3] [D loss: 0.004282, D acc: 100%] [G loss: 11.036871][well error: 13%]
# [Epoch 999,3] [D loss: 0.038041, D acc:  99%] [G loss: 6.007341][well error: 17%]
# [Epoch 999,3] [D loss: 0.031911, D acc:  99%] [G loss: 5.083425][well error: 13%]
# [Epoch 999,3] [D loss: 0.150359, D acc:  91%] [G loss: 12.326387][well error: 16%]
# [Epoch 999,3] [D loss: 0.020480, D acc:  99%] [G loss: 11.789299][well error: 15%]
# [Epoch 999,3] [D loss: 0.020109, D acc:  99%] [G loss: 10.557920][well error: 17%]
# [Epoch 999,3] [D loss: 0.045087, D acc:  98%] [G loss: 4.684981][well error: 13%]
# [Epoch 999,3] [D loss: 0.028829, D acc:  99%] [G loss: 6.217975][well error: 14%]
# [Epoch 999,3] [D loss: 0.033713, D acc:  99%] [G loss: 6.440840][well error: 23%]
# [Epoch 999,3] [D loss: 0.023290, D acc:  99%] [G loss: 8.192363][well error: 15%]
# [Epoch 999,3] [D loss: 0.026354, D acc:  99%] [G loss: 14.111402][well error: 11%]
# [Epoch 999,3] [D loss: 0.131695, D acc:  95%] [G loss: 14.025480][well error: 13%]
# [Epoch 999,3] [D loss: 0.005324, D acc: 100%] [G loss: 6.981480][well error: 14%]
# [Epoch 999,3] [D loss: 0.011162, D acc: 100%] [G loss: 7.891329][well error: 18%]
# [Epoch 999,3] [D loss: 0.005049, D acc: 100%] [G loss: 12.714163][well error: 22%]
# [Epoch 999,3] [D loss: 0.014684, D acc: 100%] [G loss: 7.341941][well error: 16%]
# [Epoch 999,3] [D loss: 0.041290, D acc:  99%] [G loss: 6.258204][well error: 20%]
# [Epoch 999,3] [D loss: 0.185121, D acc:  93%] [G loss: 5.434999][well error: 19%]
# [Epoch 999,4] [D loss: 0.011557, D acc: 100%] [G loss: 9.488431][well error: 16%]
# [Epoch 999,4] [D loss: 0.229128, D acc:  91%] [G loss: 7.828151][well error: 15%]
# [Epoch 999,4] [D loss: 0.024001, D acc:  99%] [G loss: 5.807905][well error: 15%]
# [Epoch 999,4] [D loss: 0.033187, D acc:  99%] [G loss: 7.998400][well error: 15%]
# [Epoch 999,4] [D loss: 0.010614, D acc: 100%] [G loss: 12.659654][well error: 15%]
# [Epoch 999,4] [D loss: 0.220494, D acc:  92%] [G loss: 7.791268][well error: 15%]
# [Epoch 999,4] [D loss: 0.471297, D acc:  82%] [G loss: 4.869909][well error: 16%]
# [Epoch 999,4] [D loss: 0.012408, D acc:  99%] [G loss: 12.065280][well error: 14%]
# [Epoch 999,4] [D loss: 0.054968, D acc:  98%] [G loss: 10.912412][well error: 15%]
# [Epoch 999,4] [D loss: 0.061565, D acc:  98%] [G loss: 6.167453][well error: 17%]
# [Epoch 999,4] [D loss: 0.004691, D acc: 100%] [G loss: 7.803376][well error: 18%]
# [Epoch 999,4] [D loss: 0.121180, D acc:  95%] [G loss: 6.901503][well error: 11%]
# [Epoch 999,4] [D loss: 0.026176, D acc:  99%] [G loss: 10.879230][well error: 16%]
# [Epoch 999,4] [D loss: 0.022741, D acc:  99%] [G loss: 12.428139][well error: 10%]
# [Epoch 999,4] [D loss: 0.100194, D acc:  96%] [G loss: 5.538004][well error: 19%]
# [Epoch 999,4] [D loss: 0.106743, D acc:  97%] [G loss: 3.448396][well error: 18%]
# [Epoch 999,4] [D loss: 0.010723, D acc: 100%] [G loss: 7.661790][well error: 16%]
# [Epoch 999,4] [D loss: 0.119794, D acc:  95%] [G loss: 5.639760][well error: 13%]
# [Epoch 999,4] [D loss: 0.004722, D acc: 100%] [G loss: 10.329618][well error: 20%]
# [Epoch 999,4] [D loss: 0.002473, D acc: 100%] [G loss: 9.391370][well error: 17%]
# [Epoch 999,4] [D loss: 0.009478, D acc: 100%] [G loss: 9.714573][well error: 10%]
